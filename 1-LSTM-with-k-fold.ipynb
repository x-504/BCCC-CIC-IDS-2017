# %%
import os
import numpy as np
import pandas as pd


import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout, Input, Flatten
from sklearn.model_selection import StratifiedKFold, KFold
from sklearn.pipeline import Pipeline
from tensorflow.keras.metrics import AUC
from sklearn.preprocessing import LabelEncoder, StandardScaler, MinMaxScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, accuracy_score
from sklearn.preprocessing import MultiLabelBinarizer
from sklearn.metrics import multilabel_confusion_matrix
from imblearn.under_sampling import RandomUnderSampler
from keras.optimizers import Adam

from keras.callbacks import ModelCheckpoint
from keras.models import load_model



import matplotlib.pyplot as plt
from sklearn.metrics import roc_curve, auc, RocCurveDisplay
import seaborn as sns
from itertools import cycle

# %%
# Define defaults

# Set seed for NumPy
np.random.seed(42)

FILENAME = "../../datasets/BCCC-CIC-IDS-2017/subsets/training_v1.csv"
FILENAME_TEST = "../../datasets/BCCC-CIC-IDS-2017/subsets/test_v1.csv"

# %%
# Load csv file
df = pd.read_csv(FILENAME, low_memory=False)
df_test = pd.read_csv(FILENAME_TEST, low_memory=False)

# %%
X_train = df.drop("label", axis=1)
y_train = df["label"]


X_test = df_test.drop("label", axis=1)
y_test = df_test["label"]

# %%
X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size=0.1)

# %%
y_train.value_counts()
# Out:
# label
# 0    328438
# 3    127418
# 1     42573
# 2      3460
# 4      2537
# 5      2093
# Name: count, dtype: int64

# %%
y_train.shape
# Out:
# (506519,)

# %%
y_test.value_counts()
# Out:
# label
# 0    365427
# 3    141203
# 1     47234
# 2      3863
# 4      2739
# 5      2334
# Name: count, dtype: int64

# %%
y_test.shape
# Out:
# (562800,)

# %%
# Prepration for Normalize features
scaler = MinMaxScaler(feature_range=(0, 1))
columns_to_normalize = X_train.columns.tolist()

# %%
columns_to_normalize
# Out:
# ['fwd_rst_flag_counts',
#  'rst_flag_counts',
#  'bwd_avg_segment_size',
#  'bwd_payload_bytes_variance',
#  'payload_bytes_std',
#  'bwd_payload_bytes_std',
#  'fwd_payload_bytes_std',
#  'payload_bytes_variance',
#  'payload_bytes_mean',
#  'fwd_payload_bytes_mean',
#  'bwd_payload_bytes_mean',
#  'avg_segment_size',
#  'payload_bytes_max',
#  'fwd_payload_bytes_max',
#  'bwd_payload_bytes_max',
#  'packet_IAT_min',
#  'packets_IAT_mean',
#  'packet_IAT_max',
#  'packet_IAT_total',
#  'fwd_packets_IAT_min',
#  'fwd_packets_IAT_mean',
#  'fwd_packets_IAT_total',
#  'fwd_packets_IAT_max',
#  'bwd_std_header_bytes',
#  'active_std',
#  'idle_min',
#  'idle_mean',
#  'idle_max',
#  'bwd_rst_flag_counts',
#  'fwd_std_header_bytes',
#  'std_header_bytes',
#  'fwd_syn_flag_counts',
#  'bwd_init_win_bytes',
#  'bwd_fin_flag_counts',
#  'fwd_packets_IAT_std',
#  'fwd_init_win_bytes',
#  'bwd_packets_IAT_min',
#  'bwd_packets_IAT_mean',
#  'bwd_packets_IAT_max',
#  'bwd_packets_IAT_total',
#  'bwd_max_header_bytes',
#  'packet_IAT_std',
#  'syn_flag_counts',
#  'bwd_bytes_rate',
#  'min_header_bytes',
#  'fwd_bulk_duration',
#  'bwd_mean_header_bytes',
#  'bwd_min_header_bytes',
#  'avg_bwd_bulk_rate',
#  'mean_header_bytes',
#  'bytes_rate',
#  'fwd_fin_flag_counts',
#  'bwd_packets_IAT_std',
#  'fwd_min_header_bytes',
#  'bwd_syn_flag_counts',
#  'duration',
#  'fwd_mean_header_bytes',
#  'avg_fwd_packets_per_bulk',
#  'fin_flag_counts',
#  'fwd_max_header_bytes',
#  'fwd_avg_segment_size',
#  'max_header_bytes',
#  'bwd_payload_bytes_min',
#  'fwd_payload_bytes_min',
#  'payload_bytes_min',
#  'idle_std',
#  'down_up_rate',
#  'fwd_ece_flag_counts',
#  'ece_flag_counts',
#  'bwd_ece_flag_counts',
#  'fwd_payload_bytes_variance',
#  'fwd_bulk_state_count',
#  'fwd_psh_flag_counts',
#  'fwd_packets_rate',
#  'fwd_bulk_per_packet',
#  'fwd_bytes_rate',
#  'avg_fwd_bytes_per_bulk',
#  'avg_bwd_packets_bulk_rate',
#  'packets_rate',
#  'subflow_bwd_bytes',
#  'subflow_fwd_bytes',
#  'fwd_total_payload_bytes',
#  'avg_bwd_bytes_per_bulk',
#  'psh_flag_counts',
#  'bwd_psh_flag_counts',
#  'bwd_packets_rate',
#  'bwd_bulk_duration',
#  'cwr_flag_counts',
#  'fwd_cwr_flag_counts',
#  'fwd_bulk_total_size',
#  'bwd_bulk_state_count',
#  'avg_fwd_bulk_rate',
#  'bwd_total_header_bytes',
#  'bwd_ack_flag_counts',
#  'bwd_packets_count',
#  'ack_flag_counts',
#  'packets_count',
#  'total_header_bytes',
#  'fwd_ack_flag_counts',
#  'fwd_packets_count',
#  'fwd_total_header_bytes',
#  'bwd_bulk_per_packet',
#  'total_payload_bytes',
#  'bwd_total_payload_bytes',
#  'bwd_bulk_total_size',
#  'bwd_cwr_flag_counts',
#  'subflow_fwd_packets',
#  'subflow_bwd_packets']

# %%
# Configuration for Cross Validation
kf = KFold(n_splits=5)
rus = RandomUnderSampler(random_state=42, sampling_strategy='auto')
seq_length = 1  # Number of time steps per sequence
mlb = MultiLabelBinarizer(classes=range(6))  # Specify the classes if needed (in this case, 6 labels)
histories = []
predictions = []

# %%
# ## Convert data into LSTM-friendly format
X_test = X_test.to_numpy().reshape((X_test.shape[0], 1, X_test.shape[1]))
y_test_binary = mlb.fit_transform(y_test.to_numpy().reshape(-1, 1))

# %%
for i, (train_index, val_index) in enumerate(kf.split(X_train, y_train)):
    print(f"Fold {i + 1}:")
    print(f"  Train: index={train_index}")
    print(f"  Val:  index={val_index}")
    
    
    lstm = Sequential([
    Input(shape=(1, len(columns_to_normalize))),
    LSTM(256, return_sequences=True),
    Dropout(0.2),
    LSTM(128, return_sequences=True),
    Dropout(0.2),
    LSTM(64, return_sequences=False),
    Dropout(0.2),
    Dense(32, activation="relu"),
    Dropout(0.2),
    Dense(6, activation="softmax")
    ])

    # Compile the model
    optimizer = Adam(learning_rate=0.001)
    lstm.compile(optimizer="adam", loss="categorical_crossentropy", metrics=['categorical_accuracy'])
        
    # training
    X_fold_training = X_train.iloc[train_index]
    y_fold_training = y_train.iloc[train_index]
    
    # Normalize
    X_fold_training[columns_to_normalize] = scaler.fit_transform(X_fold_training[columns_to_normalize])
    
    # RUS
    X_fold_training, y_fold_training = rus.fit_resample(X_fold_training, y_fold_training)
    
    # validation
    X_fold_val = X_train.iloc[val_index]
    y_fold_val = y_train.iloc[val_index]
    
    # Normalize
    X_fold_val[columns_to_normalize] = scaler.fit_transform(X_fold_val[columns_to_normalize])
    
    # RUS
    X_fold_val, y_fold_val = rus.fit_resample(X_fold_val, y_fold_val)
    
    # Convert data into LSTM-friendly format
    X_train_lstm, y_train_lstm = [], []
    X_val_lstm, y_val_lstm = [], []
    
    # training
    X_train_lstm = X_fold_training.to_numpy().reshape((X_fold_training.shape[0], 1, X_fold_training.shape[1]))
    
    # validation
    X_val_lstm = X_fold_val.to_numpy().reshape((X_fold_val.shape[0], 1, X_fold_val.shape[1]))
    
    # Convert y_train, y_test and y_val to MultiLabel binaries
    y_train_binary = mlb.fit_transform(y_fold_training.to_numpy().reshape(-1, 1))
    y_val_binary = mlb.fit_transform(y_fold_val.to_numpy().reshape(-1, 1))

    
    # Train Model
    history = lstm.fit(X_train_lstm, y_train_binary, epochs=100, batch_size=32, validation_data=(X_val_lstm, y_val_binary))
    histories.append(history)
    
    # Classify using the Test dataset
    y_pred = (lstm.predict(X_test) > 0.5).astype("int32")
    predictions.append(y_pred)
# Out:
# Fold 1:
#   Train: index=[101304 101305 101306 ... 506516 506517 506518]
#   Val:  index=[     0      1      2 ... 101301 101302 101303]
# /var/folders/qg/czgp8gyn3057jghb1vm_44yr0000gp/T/ipykernel_10232/3521911706.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_fold_training[columns_to_normalize] = scaler.fit_transform(X_fold_training[columns_to_normalize])
# Epoch 1/100
# /var/folders/qg/czgp8gyn3057jghb1vm_44yr0000gp/T/ipykernel_10232/3521911706.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_fold_val[columns_to_normalize] = scaler.fit_transform(X_fold_val[columns_to_normalize])
# 311/311 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - categorical_accuracy: 0.4601 - loss: 1.3029 - val_categorical_accuracy: 0.8460 - val_loss: 0.5494
# Epoch 2/100
# 311/311 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - categorical_accuracy: 0.8113 - loss: 0.5410 - val_categorical_accuracy: 0.8720 - val_loss: 0.3538
# Epoch 3/100
# 311/311 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - categorical_accuracy: 0.8460 - loss: 0.4162 - val_categorical_accuracy: 0.8843 - val_loss: 0.3096
# Epoch 4/100
# 311/311 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - categorical_accuracy: 0.8675 - loss: 0.3621 - val_categorical_accuracy: 0.8858 - val_loss: 0.3140
# Epoch 5/100
# 311/311 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - categorical_accuracy: 0.8776 - loss: 0.3381 - val_categorical_accuracy: 0.8713 - val_loss: 0.3671
# Epoch 6/100
# 311/311 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - categorical_accuracy: 0.8812 - loss: 0.3253 - val_categorical_accuracy: 0.8923 - val_loss: 0.3033
# Epoch 7/100
# 311/311 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - categorical_accuracy: 0.8824 - loss: 0.3242 - val_categorical_accuracy: 0.8969 - val_loss: 0.2859
# Epoch 8/100
# 311/311 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - categorical_accuracy: 0.8994 - loss: 0.2831 - val_categorical_accuracy: 0.9038 - val_loss: 0.2674
# Epoch 9/100
# 311/311 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - categorical_accuracy: 0.8912 - loss: 0.3055 - val_categorical_accuracy: 0.8908 - val_loss: 0.3040
# Epoch 10/100
# 311/311 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - categorical_accuracy: 0.8903 - loss: 0.2924 - val_categorical_accuracy: 0.9031 - val_loss: 0.2532
# Epoch 11/100
# 311/311 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - categorical_accuracy: 0.8987 - loss: 0.2846 - val_categorical_accuracy: 0.8966 - val_loss: 0.2739
# Epoch 12/100
# 311/311 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - categorical_accuracy: 0.8986 - loss: 0.2779 - val_categorical_accuracy: 0.9050 - val_loss: 0.2592
# Epoch 13/100
# 311/311 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - categorical_accuracy: 0.8987 - loss: 0.2793 - val_categorical_accuracy: 0.8943 - val_loss: 0.3034
# Epoch 14/100
# 311/311 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - categorical_accuracy: 0.8997 - loss: 0.2662 - val_categorical_accuracy: 0.9038 - val_loss: 0.2560
# Epoch 15/100
# 311/311 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - categorical_accuracy: 0.9010 - loss: 0.2685 - val_categorical_accuracy: 0.8985 - val_loss: 0.2888
# Epoch 16/100
# 311/311 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - categorical_accuracy: 0.8992 - loss: 0.2647 - val_categorical_accuracy: 0.8923 - val_loss: 0.2885
# Epoch 17/100
# 311/311 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - categorical_accuracy: 0.9036 - loss: 0.2577 - val_categorical_accuracy: 0.8912 - val_loss: 0.3004
# Epoch 18/100
# 311/311 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - categorical_accuracy: 0.9057 - loss: 0.2545 - val_categorical_accuracy: 0.9100 - val_loss: 0.2428
# Epoch 19/100
# 311/311 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - categorical_accuracy: 0.9001 - loss: 0.2722 - val_categorical_accuracy: 0.8789 - val_loss: 0.3666
# Epoch 20/100
# 311/311 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - categorical_accuracy: 0.9086 - loss: 0.2428 - val_categorical_accuracy: 0.9054 - val_loss: 0.2410
# Epoch 21/100
# 311/311 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - categorical_accuracy: 0.9071 - loss: 0.2475 - val_categorical_accuracy: 0.9034 - val_loss: 0.2506
# Epoch 22/100
# 311/311 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - categorical_accuracy: 0.9092 - loss: 0.2416 - val_categorical_accuracy: 0.9092 - val_loss: 0.2520
# Epoch 23/100
# 311/311 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - categorical_accuracy: 0.9091 - loss: 0.2401 - val_categorical_accuracy: 0.9123 - val_loss: 0.2348
# Epoch 24/100
# 311/311 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - categorical_accuracy: 0.9079 - loss: 0.2390 - val_categorical_accuracy: 0.9057 - val_loss: 0.2487
# Epoch 25/100
# 311/311 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - categorical_accuracy: 0.9088 - loss: 0.2409 - val_categorical_accuracy: 0.9080 - val_loss: 0.2471
# Epoch 26/100
# 311/311 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - categorical_accuracy: 0.9052 - loss: 0.2461 - val_categorical_accuracy: 0.9138 - val_loss: 0.2252
# Epoch 27/100
# 311/311 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - categorical_accuracy: 0.9097 - loss: 0.2335 - val_categorical_accuracy: 0.9111 - val_loss: 0.2317
# Epoch 28/100
# 311/311 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - categorical_accuracy: 0.9073 - loss: 0.2425 - val_categorical_accuracy: 0.9107 - val_loss: 0.2384
# Epoch 29/100
# 311/311 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - categorical_accuracy: 0.9132 - loss: 0.2266 - val_categorical_accuracy: 0.9092 - val_loss: 0.2403
# Epoch 30/100
# 311/311 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - categorical_accuracy: 0.9085 - loss: 0.2407 - val_categorical_accuracy: 0.9084 - val_loss: 0.2345
# Epoch 31/100
# 311/311 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - categorical_accuracy: 0.9074 - loss: 0.2391 - val_categorical_accuracy: 0.9119 - val_loss: 0.2372
# Epoch 32/100
# 311/311 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - categorical_accuracy: 0.9158 - loss: 0.2278 - val_categorical_accuracy: 0.9069 - val_loss: 0.2470
# Epoch 33/100
# 311/311 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - categorical_accuracy: 0.9068 - loss: 0.2464 - val_categorical_accuracy: 0.9146 - val_loss: 0.2183
# Epoch 34/100
# 311/311 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - categorical_accuracy: 0.9115 - loss: 0.2345 - val_categorical_accuracy: 0.9130 - val_loss: 0.2345
# Epoch 35/100
# 311/311 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - categorical_accuracy: 0.9097 - loss: 0.2386 - val_categorical_accuracy: 0.9130 - val_loss: 0.2256
# Epoch 36/100
# 311/311 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - categorical_accuracy: 0.9095 - loss: 0.2369 - val_categorical_accuracy: 0.9134 - val_loss: 0.2372
# Epoch 37/100
# 311/311 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - categorical_accuracy: 0.9103 - loss: 0.2301 - val_categorical_accuracy: 0.9134 - val_loss: 0.2269
# Epoch 38/100
# 311/311 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - categorical_accuracy: 0.9082 - loss: 0.2360 - val_categorical_accuracy: 0.9042 - val_loss: 0.2525
# Epoch 39/100
# 311/311 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - categorical_accuracy: 0.9062 - loss: 0.2401 - val_categorical_accuracy: 0.9126 - val_loss: 0.2264
# Epoch 40/100
# 311/311 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - categorical_accuracy: 0.9140 - loss: 0.2282 - val_categorical_accuracy: 0.9119 - val_loss: 0.2217
# Epoch 41/100
# 311/311 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - categorical_accuracy: 0.9123 - loss: 0.2313 - val_categorical_accuracy: 0.9134 - val_loss: 0.2213
# Epoch 42/100
# 311/311 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - categorical_accuracy: 0.9129 - loss: 0.2325 - val_categorical_accuracy: 0.8950 - val_loss: 0.3608
# Epoch 43/100
# 311/311 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - categorical_accuracy: 0.9148 - loss: 0.2336 - val_categorical_accuracy: 0.9142 - val_loss: 0.2226
# Epoch 44/100
# 311/311 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - categorical_accuracy: 0.9104 - loss: 0.2324 - val_categorical_accuracy: 0.9180 - val_loss: 0.2081
# Epoch 45/100
# 311/311 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - categorical_accuracy: 0.9119 - loss: 0.2264 - val_categorical_accuracy: 0.9172 - val_loss: 0.2125
# Epoch 46/100
# 311/311 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - categorical_accuracy: 0.9123 - loss: 0.2252 - val_categorical_accuracy: 0.9130 - val_loss: 0.2419
# Epoch 47/100
# 311/311 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - categorical_accuracy: 0.9091 - loss: 0.2348 - val_categorical_accuracy: 0.9149 - val_loss: 0.2259
# Epoch 48/100
# 311/311 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - categorical_accuracy: 0.9213 - loss: 0.2106 - val_categorical_accuracy: 0.9149 - val_loss: 0.2284
# Epoch 49/100
# 311/311 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - categorical_accuracy: 0.9165 - loss: 0.2169 - val_categorical_accuracy: 0.9153 - val_loss: 0.2326
# Epoch 50/100
# 311/311 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - categorical_accuracy: 0.9130 - loss: 0.2226 - val_categorical_accuracy: 0.8950 - val_loss: 0.3003
# Epoch 51/100
# 311/311 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - categorical_accuracy: 0.9093 - loss: 0.2356 - val_categorical_accuracy: 0.9111 - val_loss: 0.2444
# Epoch 52/100
# 311/311 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - categorical_accuracy: 0.9177 - loss: 0.2097 - val_categorical_accuracy: 0.9176 - val_loss: 0.2067
# Epoch 53/100
# 311/311 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - categorical_accuracy: 0.9068 - loss: 0.2428 - val_categorical_accuracy: 0.9165 - val_loss: 0.2247
# Epoch 54/100
# 311/311 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - categorical_accuracy: 0.9099 - loss: 0.2327 - val_categorical_accuracy: 0.9088 - val_loss: 0.2460
# Epoch 55/100
# 311/311 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - categorical_accuracy: 0.9178 - loss: 0.2131 - val_categorical_accuracy: 0.9031 - val_loss: 0.2699
# Epoch 56/100
# 311/311 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - categorical_accuracy: 0.9117 - loss: 0.2286 - val_categorical_accuracy: 0.9115 - val_loss: 0.2298
# Epoch 57/100
# 311/311 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - categorical_accuracy: 0.9163 - loss: 0.2194 - val_categorical_accuracy: 0.9184 - val_loss: 0.2133
# Epoch 58/100
# 311/311 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - categorical_accuracy: 0.9096 - loss: 0.2355 - val_categorical_accuracy: 0.9184 - val_loss: 0.2138
# Epoch 59/100
# 311/311 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - categorical_accuracy: 0.9172 - loss: 0.2198 - val_categorical_accuracy: 0.9080 - val_loss: 0.2542
# Epoch 60/100
# 311/311 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - categorical_accuracy: 0.9153 - loss: 0.2240 - val_categorical_accuracy: 0.9203 - val_loss: 0.2091
# Epoch 61/100
# 311/311 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - categorical_accuracy: 0.9147 - loss: 0.2203 - val_categorical_accuracy: 0.9153 - val_loss: 0.2293
# Epoch 62/100
# 311/311 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - categorical_accuracy: 0.9204 - loss: 0.2042 - val_categorical_accuracy: 0.9153 - val_loss: 0.2230
# Epoch 63/100
# 311/311 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - categorical_accuracy: 0.9162 - loss: 0.2147 - val_categorical_accuracy: 0.9134 - val_loss: 0.2386
# Epoch 64/100
# 311/311 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - categorical_accuracy: 0.9096 - loss: 0.2330 - val_categorical_accuracy: 0.9142 - val_loss: 0.2343
# Epoch 65/100
# 311/311 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - categorical_accuracy: 0.9163 - loss: 0.2225 - val_categorical_accuracy: 0.9157 - val_loss: 0.2236
# Epoch 66/100
# 311/311 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - categorical_accuracy: 0.9126 - loss: 0.2272 - val_categorical_accuracy: 0.9172 - val_loss: 0.2154
# Epoch 67/100
# 311/311 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - categorical_accuracy: 0.9103 - loss: 0.2281 - val_categorical_accuracy: 0.9192 - val_loss: 0.2109
# Epoch 68/100
# 311/311 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - categorical_accuracy: 0.9141 - loss: 0.2169 - val_categorical_accuracy: 0.9169 - val_loss: 0.2170
# Epoch 69/100
# 311/311 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - categorical_accuracy: 0.9126 - loss: 0.2286 - val_categorical_accuracy: 0.9192 - val_loss: 0.2118
# Epoch 70/100
# 311/311 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - categorical_accuracy: 0.9168 - loss: 0.2068 - val_categorical_accuracy: 0.9157 - val_loss: 0.2241
# Epoch 71/100
# 311/311 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - categorical_accuracy: 0.9152 - loss: 0.2147 - val_categorical_accuracy: 0.9180 - val_loss: 0.2169
# Epoch 72/100
# 311/311 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - categorical_accuracy: 0.9136 - loss: 0.2244 - val_categorical_accuracy: 0.9130 - val_loss: 0.2292
# Epoch 73/100
# 311/311 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - categorical_accuracy: 0.9095 - loss: 0.2319 - val_categorical_accuracy: 0.9165 - val_loss: 0.2217
# Epoch 74/100
# 311/311 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - categorical_accuracy: 0.9160 - loss: 0.2162 - val_categorical_accuracy: 0.9199 - val_loss: 0.2043
# Epoch 75/100
# 311/311 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - categorical_accuracy: 0.9177 - loss: 0.2112 - val_categorical_accuracy: 0.9172 - val_loss: 0.2132
# Epoch 76/100
# 311/311 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - categorical_accuracy: 0.9137 - loss: 0.2252 - val_categorical_accuracy: 0.9176 - val_loss: 0.2161
# Epoch 77/100
# 311/311 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - categorical_accuracy: 0.9139 - loss: 0.2180 - val_categorical_accuracy: 0.9119 - val_loss: 0.2418
# Epoch 78/100
# 311/311 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - categorical_accuracy: 0.9149 - loss: 0.2204 - val_categorical_accuracy: 0.9134 - val_loss: 0.2253
# Epoch 79/100
# 311/311 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - categorical_accuracy: 0.9177 - loss: 0.2108 - val_categorical_accuracy: 0.9107 - val_loss: 0.2308
# Epoch 80/100
# 311/311 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - categorical_accuracy: 0.9160 - loss: 0.2124 - val_categorical_accuracy: 0.9138 - val_loss: 0.2269
# Epoch 81/100
# 311/311 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - categorical_accuracy: 0.9171 - loss: 0.2086 - val_categorical_accuracy: 0.9184 - val_loss: 0.2122
# Epoch 82/100
# 311/311 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - categorical_accuracy: 0.9112 - loss: 0.2231 - val_categorical_accuracy: 0.9188 - val_loss: 0.2074
# Epoch 83/100
# 311/311 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - categorical_accuracy: 0.9149 - loss: 0.2156 - val_categorical_accuracy: 0.9172 - val_loss: 0.2149
# Epoch 84/100
# 311/311 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - categorical_accuracy: 0.9148 - loss: 0.2157 - val_categorical_accuracy: 0.9165 - val_loss: 0.2341
# Epoch 85/100
# 311/311 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - categorical_accuracy: 0.9106 - loss: 0.2242 - val_categorical_accuracy: 0.9161 - val_loss: 0.2214
# Epoch 86/100
# 311/311 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - categorical_accuracy: 0.9165 - loss: 0.2168 - val_categorical_accuracy: 0.9119 - val_loss: 0.2425
# Epoch 87/100
# 311/311 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - categorical_accuracy: 0.9149 - loss: 0.2168 - val_categorical_accuracy: 0.9199 - val_loss: 0.2115
# Epoch 88/100
# 311/311 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - categorical_accuracy: 0.9173 - loss: 0.2131 - val_categorical_accuracy: 0.9192 - val_loss: 0.2060
# Epoch 89/100
# 311/311 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - categorical_accuracy: 0.9136 - loss: 0.2240 - val_categorical_accuracy: 0.9192 - val_loss: 0.2058
# Epoch 90/100
# 311/311 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - categorical_accuracy: 0.9154 - loss: 0.2150 - val_categorical_accuracy: 0.9192 - val_loss: 0.2108
# Epoch 91/100
# 311/311 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - categorical_accuracy: 0.9193 - loss: 0.2098 - val_categorical_accuracy: 0.9138 - val_loss: 0.2273
# Epoch 92/100
# 311/311 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - categorical_accuracy: 0.9184 - loss: 0.2116 - val_categorical_accuracy: 0.9195 - val_loss: 0.2118
# Epoch 93/100
# 311/311 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - categorical_accuracy: 0.9173 - loss: 0.2114 - val_categorical_accuracy: 0.9176 - val_loss: 0.2119
# Epoch 94/100
# 311/311 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - categorical_accuracy: 0.9165 - loss: 0.2116 - val_categorical_accuracy: 0.9184 - val_loss: 0.2140
# Epoch 95/100
# 311/311 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - categorical_accuracy: 0.9150 - loss: 0.2165 - val_categorical_accuracy: 0.9195 - val_loss: 0.2104
# Epoch 96/100
# 311/311 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - categorical_accuracy: 0.9225 - loss: 0.2000 - val_categorical_accuracy: 0.9180 - val_loss: 0.2156
# Epoch 97/100
# 311/311 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - categorical_accuracy: 0.9200 - loss: 0.2108 - val_categorical_accuracy: 0.9165 - val_loss: 0.2202
# Epoch 98/100
# 311/311 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - categorical_accuracy: 0.9166 - loss: 0.2101 - val_categorical_accuracy: 0.9065 - val_loss: 0.2553
# Epoch 99/100
# 311/311 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - categorical_accuracy: 0.9135 - loss: 0.2166 - val_categorical_accuracy: 0.8981 - val_loss: 0.4510
# Epoch 100/100
# 311/311 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - categorical_accuracy: 0.9155 - loss: 0.2206 - val_categorical_accuracy: 0.9180 - val_loss: 0.2236
# 17588/17588 ━━━━━━━━━━━━━━━━━━━━ 16s 915us/step
# Fold 2:
#   Train: index=[     0      1      2 ... 506516 506517 506518]
#   Val:  index=[101304 101305 101306 ... 202605 202606 202607]
# /var/folders/qg/czgp8gyn3057jghb1vm_44yr0000gp/T/ipykernel_10232/3521911706.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_fold_training[columns_to_normalize] = scaler.fit_transform(X_fold_training[columns_to_normalize])
# /var/folders/qg/czgp8gyn3057jghb1vm_44yr0000gp/T/ipykernel_10232/3521911706.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_fold_val[columns_to_normalize] = scaler.fit_transform(X_fold_val[columns_to_normalize])
# Epoch 1/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - categorical_accuracy: 0.4963 - loss: 1.2609 - val_categorical_accuracy: 0.8559 - val_loss: 0.4734
# Epoch 2/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - categorical_accuracy: 0.8319 - loss: 0.4940 - val_categorical_accuracy: 0.8664 - val_loss: 0.3579
# Epoch 3/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - categorical_accuracy: 0.8637 - loss: 0.3957 - val_categorical_accuracy: 0.8754 - val_loss: 0.3427
# Epoch 4/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - categorical_accuracy: 0.8864 - loss: 0.3295 - val_categorical_accuracy: 0.8672 - val_loss: 0.3489
# Epoch 5/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - categorical_accuracy: 0.8928 - loss: 0.3101 - val_categorical_accuracy: 0.8952 - val_loss: 0.2881
# Epoch 6/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - categorical_accuracy: 0.8939 - loss: 0.3029 - val_categorical_accuracy: 0.8723 - val_loss: 0.3221
# Epoch 7/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - categorical_accuracy: 0.8994 - loss: 0.2836 - val_categorical_accuracy: 0.8933 - val_loss: 0.2848
# Epoch 8/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - categorical_accuracy: 0.8954 - loss: 0.2959 - val_categorical_accuracy: 0.8988 - val_loss: 0.2694
# Epoch 9/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - categorical_accuracy: 0.9034 - loss: 0.2730 - val_categorical_accuracy: 0.8746 - val_loss: 0.2896
# Epoch 10/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - categorical_accuracy: 0.9070 - loss: 0.2615 - val_categorical_accuracy: 0.8933 - val_loss: 0.2810
# Epoch 11/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - categorical_accuracy: 0.9021 - loss: 0.2626 - val_categorical_accuracy: 0.8933 - val_loss: 0.2732
# Epoch 12/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - categorical_accuracy: 0.9075 - loss: 0.2637 - val_categorical_accuracy: 0.8991 - val_loss: 0.2723
# Epoch 13/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - categorical_accuracy: 0.9092 - loss: 0.2535 - val_categorical_accuracy: 0.8984 - val_loss: 0.2614
# Epoch 14/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - categorical_accuracy: 0.9075 - loss: 0.2512 - val_categorical_accuracy: 0.8991 - val_loss: 0.2632
# Epoch 15/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - categorical_accuracy: 0.9082 - loss: 0.2539 - val_categorical_accuracy: 0.8972 - val_loss: 0.2678
# Epoch 16/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - categorical_accuracy: 0.9114 - loss: 0.2432 - val_categorical_accuracy: 0.9003 - val_loss: 0.2554
# Epoch 17/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - categorical_accuracy: 0.9089 - loss: 0.2444 - val_categorical_accuracy: 0.8906 - val_loss: 0.2924
# Epoch 18/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - categorical_accuracy: 0.9118 - loss: 0.2383 - val_categorical_accuracy: 0.8921 - val_loss: 0.2797
# Epoch 19/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - categorical_accuracy: 0.9102 - loss: 0.2451 - val_categorical_accuracy: 0.8855 - val_loss: 0.2861
# Epoch 20/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - categorical_accuracy: 0.9171 - loss: 0.2329 - val_categorical_accuracy: 0.8960 - val_loss: 0.2755
# Epoch 21/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - categorical_accuracy: 0.9104 - loss: 0.2433 - val_categorical_accuracy: 0.9023 - val_loss: 0.2465
# Epoch 22/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - categorical_accuracy: 0.9068 - loss: 0.2505 - val_categorical_accuracy: 0.8945 - val_loss: 0.2728
# Epoch 23/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - categorical_accuracy: 0.9156 - loss: 0.2253 - val_categorical_accuracy: 0.8692 - val_loss: 0.3148
# Epoch 24/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - categorical_accuracy: 0.9036 - loss: 0.2473 - val_categorical_accuracy: 0.9038 - val_loss: 0.2469
# Epoch 25/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - categorical_accuracy: 0.9101 - loss: 0.2295 - val_categorical_accuracy: 0.9030 - val_loss: 0.2454
# Epoch 26/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - categorical_accuracy: 0.9151 - loss: 0.2288 - val_categorical_accuracy: 0.9042 - val_loss: 0.2525
# Epoch 27/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - categorical_accuracy: 0.9147 - loss: 0.2307 - val_categorical_accuracy: 0.8972 - val_loss: 0.2691
# Epoch 28/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - categorical_accuracy: 0.9127 - loss: 0.2358 - val_categorical_accuracy: 0.8988 - val_loss: 0.2708
# Epoch 29/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - categorical_accuracy: 0.9092 - loss: 0.2316 - val_categorical_accuracy: 0.9007 - val_loss: 0.2566
# Epoch 30/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - categorical_accuracy: 0.9132 - loss: 0.2212 - val_categorical_accuracy: 0.8988 - val_loss: 0.2608
# Epoch 31/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - categorical_accuracy: 0.9161 - loss: 0.2197 - val_categorical_accuracy: 0.8968 - val_loss: 0.2690
# Epoch 32/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - categorical_accuracy: 0.9119 - loss: 0.2329 - val_categorical_accuracy: 0.9023 - val_loss: 0.2550
# Epoch 33/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - categorical_accuracy: 0.9173 - loss: 0.2274 - val_categorical_accuracy: 0.8902 - val_loss: 0.3075
# Epoch 34/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - categorical_accuracy: 0.9143 - loss: 0.2132 - val_categorical_accuracy: 0.9011 - val_loss: 0.2564
# Epoch 35/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - categorical_accuracy: 0.9142 - loss: 0.2184 - val_categorical_accuracy: 0.9003 - val_loss: 0.2653
# Epoch 36/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - categorical_accuracy: 0.9109 - loss: 0.2283 - val_categorical_accuracy: 0.9030 - val_loss: 0.2574
# Epoch 37/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - categorical_accuracy: 0.9129 - loss: 0.2278 - val_categorical_accuracy: 0.9011 - val_loss: 0.2588
# Epoch 38/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - categorical_accuracy: 0.9127 - loss: 0.2209 - val_categorical_accuracy: 0.9081 - val_loss: 0.2602
# Epoch 39/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - categorical_accuracy: 0.9187 - loss: 0.2162 - val_categorical_accuracy: 0.9046 - val_loss: 0.2536
# Epoch 40/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - categorical_accuracy: 0.9143 - loss: 0.2195 - val_categorical_accuracy: 0.8917 - val_loss: 0.2964
# Epoch 41/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - categorical_accuracy: 0.9143 - loss: 0.2228 - val_categorical_accuracy: 0.9030 - val_loss: 0.2517
# Epoch 42/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - categorical_accuracy: 0.9162 - loss: 0.2243 - val_categorical_accuracy: 0.9007 - val_loss: 0.2598
# Epoch 43/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - categorical_accuracy: 0.9215 - loss: 0.2064 - val_categorical_accuracy: 0.9011 - val_loss: 0.2589
# Epoch 44/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - categorical_accuracy: 0.9210 - loss: 0.2043 - val_categorical_accuracy: 0.9073 - val_loss: 0.2555
# Epoch 45/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - categorical_accuracy: 0.9170 - loss: 0.2118 - val_categorical_accuracy: 0.9062 - val_loss: 0.2576
# Epoch 46/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - categorical_accuracy: 0.9180 - loss: 0.2142 - val_categorical_accuracy: 0.9077 - val_loss: 0.2530
# Epoch 47/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - categorical_accuracy: 0.9211 - loss: 0.2057 - val_categorical_accuracy: 0.9034 - val_loss: 0.2538
# Epoch 48/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - categorical_accuracy: 0.9165 - loss: 0.2150 - val_categorical_accuracy: 0.9042 - val_loss: 0.2619
# Epoch 49/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - categorical_accuracy: 0.9152 - loss: 0.2202 - val_categorical_accuracy: 0.8984 - val_loss: 0.2682
# Epoch 50/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - categorical_accuracy: 0.9153 - loss: 0.2141 - val_categorical_accuracy: 0.9050 - val_loss: 0.2541
# Epoch 51/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - categorical_accuracy: 0.9189 - loss: 0.2161 - val_categorical_accuracy: 0.9046 - val_loss: 0.2606
# Epoch 52/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - categorical_accuracy: 0.9191 - loss: 0.2141 - val_categorical_accuracy: 0.8991 - val_loss: 0.2700
# Epoch 53/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - categorical_accuracy: 0.9145 - loss: 0.2159 - val_categorical_accuracy: 0.8999 - val_loss: 0.2713
# Epoch 54/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - categorical_accuracy: 0.9199 - loss: 0.2142 - val_categorical_accuracy: 0.8960 - val_loss: 0.2859
# Epoch 55/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - categorical_accuracy: 0.9117 - loss: 0.2289 - val_categorical_accuracy: 0.8941 - val_loss: 0.2720
# Epoch 56/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - categorical_accuracy: 0.9175 - loss: 0.2097 - val_categorical_accuracy: 0.9046 - val_loss: 0.2591
# Epoch 57/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - categorical_accuracy: 0.9179 - loss: 0.2164 - val_categorical_accuracy: 0.8999 - val_loss: 0.2788
# Epoch 58/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - categorical_accuracy: 0.9241 - loss: 0.1982 - val_categorical_accuracy: 0.9026 - val_loss: 0.2737
# Epoch 59/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - categorical_accuracy: 0.9228 - loss: 0.2011 - val_categorical_accuracy: 0.9046 - val_loss: 0.2601
# Epoch 60/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - categorical_accuracy: 0.9182 - loss: 0.2084 - val_categorical_accuracy: 0.8910 - val_loss: 0.3090
# Epoch 61/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - categorical_accuracy: 0.9196 - loss: 0.2051 - val_categorical_accuracy: 0.9026 - val_loss: 0.2842
# Epoch 62/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - categorical_accuracy: 0.9231 - loss: 0.2097 - val_categorical_accuracy: 0.8960 - val_loss: 0.3008
# Epoch 63/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - categorical_accuracy: 0.9163 - loss: 0.2122 - val_categorical_accuracy: 0.9030 - val_loss: 0.2745
# Epoch 64/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - categorical_accuracy: 0.9180 - loss: 0.2116 - val_categorical_accuracy: 0.9089 - val_loss: 0.2548
# Epoch 65/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - categorical_accuracy: 0.9205 - loss: 0.1988 - val_categorical_accuracy: 0.9065 - val_loss: 0.2615
# Epoch 66/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - categorical_accuracy: 0.9256 - loss: 0.1965 - val_categorical_accuracy: 0.9042 - val_loss: 0.2680
# Epoch 67/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - categorical_accuracy: 0.9154 - loss: 0.2157 - val_categorical_accuracy: 0.9054 - val_loss: 0.2704
# Epoch 68/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - categorical_accuracy: 0.9194 - loss: 0.2109 - val_categorical_accuracy: 0.9050 - val_loss: 0.2645
# Epoch 69/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - categorical_accuracy: 0.9169 - loss: 0.2129 - val_categorical_accuracy: 0.8956 - val_loss: 0.3022
# Epoch 70/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - categorical_accuracy: 0.9163 - loss: 0.2215 - val_categorical_accuracy: 0.8984 - val_loss: 0.2877
# Epoch 71/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - categorical_accuracy: 0.9189 - loss: 0.2116 - val_categorical_accuracy: 0.8960 - val_loss: 0.2860
# Epoch 72/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - categorical_accuracy: 0.9233 - loss: 0.1958 - val_categorical_accuracy: 0.9030 - val_loss: 0.2725
# Epoch 73/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - categorical_accuracy: 0.9204 - loss: 0.2027 - val_categorical_accuracy: 0.8847 - val_loss: 0.3325
# Epoch 74/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - categorical_accuracy: 0.9162 - loss: 0.2138 - val_categorical_accuracy: 0.9077 - val_loss: 0.2528
# Epoch 75/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - categorical_accuracy: 0.9179 - loss: 0.2087 - val_categorical_accuracy: 0.8945 - val_loss: 0.3037
# Epoch 76/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - categorical_accuracy: 0.9249 - loss: 0.2014 - val_categorical_accuracy: 0.9054 - val_loss: 0.2679
# Epoch 77/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - categorical_accuracy: 0.9162 - loss: 0.2116 - val_categorical_accuracy: 0.9038 - val_loss: 0.2733
# Epoch 78/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - categorical_accuracy: 0.9210 - loss: 0.2092 - val_categorical_accuracy: 0.9023 - val_loss: 0.2704
# Epoch 79/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - categorical_accuracy: 0.9210 - loss: 0.2176 - val_categorical_accuracy: 0.9042 - val_loss: 0.2753
# Epoch 80/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - categorical_accuracy: 0.9175 - loss: 0.2076 - val_categorical_accuracy: 0.9069 - val_loss: 0.2574
# Epoch 81/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - categorical_accuracy: 0.9220 - loss: 0.2024 - val_categorical_accuracy: 0.8968 - val_loss: 0.2994
# Epoch 82/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - categorical_accuracy: 0.9210 - loss: 0.2015 - val_categorical_accuracy: 0.9054 - val_loss: 0.2727
# Epoch 83/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - categorical_accuracy: 0.9183 - loss: 0.2199 - val_categorical_accuracy: 0.8917 - val_loss: 0.3132
# Epoch 84/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - categorical_accuracy: 0.9247 - loss: 0.1996 - val_categorical_accuracy: 0.9073 - val_loss: 0.2581
# Epoch 85/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - categorical_accuracy: 0.9245 - loss: 0.1922 - val_categorical_accuracy: 0.9062 - val_loss: 0.2647
# Epoch 86/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - categorical_accuracy: 0.9220 - loss: 0.1966 - val_categorical_accuracy: 0.9073 - val_loss: 0.2554
# Epoch 87/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - categorical_accuracy: 0.9220 - loss: 0.2025 - val_categorical_accuracy: 0.9069 - val_loss: 0.2652
# Epoch 88/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - categorical_accuracy: 0.9180 - loss: 0.2062 - val_categorical_accuracy: 0.9050 - val_loss: 0.2670
# Epoch 89/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - categorical_accuracy: 0.9205 - loss: 0.1979 - val_categorical_accuracy: 0.9077 - val_loss: 0.2699
# Epoch 90/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - categorical_accuracy: 0.9191 - loss: 0.2061 - val_categorical_accuracy: 0.8995 - val_loss: 0.2856
# Epoch 91/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - categorical_accuracy: 0.9210 - loss: 0.2021 - val_categorical_accuracy: 0.9073 - val_loss: 0.2677
# Epoch 92/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - categorical_accuracy: 0.9249 - loss: 0.1971 - val_categorical_accuracy: 0.8991 - val_loss: 0.2826
# Epoch 93/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - categorical_accuracy: 0.9211 - loss: 0.1980 - val_categorical_accuracy: 0.9062 - val_loss: 0.2612
# Epoch 94/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - categorical_accuracy: 0.9163 - loss: 0.2062 - val_categorical_accuracy: 0.9007 - val_loss: 0.2787
# Epoch 95/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - categorical_accuracy: 0.9205 - loss: 0.2007 - val_categorical_accuracy: 0.9050 - val_loss: 0.2704
# Epoch 96/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - categorical_accuracy: 0.9168 - loss: 0.2064 - val_categorical_accuracy: 0.8999 - val_loss: 0.2838
# Epoch 97/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - categorical_accuracy: 0.9205 - loss: 0.2082 - val_categorical_accuracy: 0.9073 - val_loss: 0.2648
# Epoch 98/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - categorical_accuracy: 0.9185 - loss: 0.2064 - val_categorical_accuracy: 0.9077 - val_loss: 0.2615
# Epoch 99/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - categorical_accuracy: 0.9169 - loss: 0.2134 - val_categorical_accuracy: 0.9058 - val_loss: 0.2643
# Epoch 100/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - categorical_accuracy: 0.9239 - loss: 0.1916 - val_categorical_accuracy: 0.9093 - val_loss: 0.2556
# 17588/17588 ━━━━━━━━━━━━━━━━━━━━ 14s 805us/step
# Fold 3:
#   Train: index=[     0      1      2 ... 506516 506517 506518]
#   Val:  index=[202608 202609 202610 ... 303909 303910 303911]
# /var/folders/qg/czgp8gyn3057jghb1vm_44yr0000gp/T/ipykernel_10232/3521911706.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_fold_training[columns_to_normalize] = scaler.fit_transform(X_fold_training[columns_to_normalize])
# /var/folders/qg/czgp8gyn3057jghb1vm_44yr0000gp/T/ipykernel_10232/3521911706.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_fold_val[columns_to_normalize] = scaler.fit_transform(X_fold_val[columns_to_normalize])
# Epoch 1/100
# 311/311 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - categorical_accuracy: 0.4622 - loss: 1.2894 - val_categorical_accuracy: 0.8299 - val_loss: 0.5067
# Epoch 2/100
# 311/311 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - categorical_accuracy: 0.8317 - loss: 0.4939 - val_categorical_accuracy: 0.8433 - val_loss: 0.4146
# Epoch 3/100
# 311/311 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - categorical_accuracy: 0.8643 - loss: 0.3927 - val_categorical_accuracy: 0.8448 - val_loss: 0.4269
# Epoch 4/100
# 311/311 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - categorical_accuracy: 0.8804 - loss: 0.3485 - val_categorical_accuracy: 0.8153 - val_loss: 0.5358
# Epoch 5/100
# 311/311 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - categorical_accuracy: 0.8857 - loss: 0.3317 - val_categorical_accuracy: 0.8510 - val_loss: 0.3881
# Epoch 6/100
# 311/311 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - categorical_accuracy: 0.8892 - loss: 0.3128 - val_categorical_accuracy: 0.8655 - val_loss: 0.3405
# Epoch 7/100
# 311/311 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - categorical_accuracy: 0.8888 - loss: 0.3134 - val_categorical_accuracy: 0.8797 - val_loss: 0.3089
# Epoch 8/100
# 311/311 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - categorical_accuracy: 0.8956 - loss: 0.2880 - val_categorical_accuracy: 0.8494 - val_loss: 0.4172
# Epoch 9/100
# 311/311 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - categorical_accuracy: 0.8949 - loss: 0.3088 - val_categorical_accuracy: 0.8579 - val_loss: 0.4516
# Epoch 10/100
# 311/311 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - categorical_accuracy: 0.8971 - loss: 0.2895 - val_categorical_accuracy: 0.8571 - val_loss: 0.4225
# Epoch 11/100
# 311/311 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - categorical_accuracy: 0.8975 - loss: 0.2787 - val_categorical_accuracy: 0.8536 - val_loss: 0.4736
# Epoch 12/100
# 311/311 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - categorical_accuracy: 0.9001 - loss: 0.2686 - val_categorical_accuracy: 0.8870 - val_loss: 0.3302
# Epoch 13/100
# 311/311 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - categorical_accuracy: 0.9022 - loss: 0.2709 - val_categorical_accuracy: 0.8693 - val_loss: 0.3971
# Epoch 14/100
# 311/311 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - categorical_accuracy: 0.9054 - loss: 0.2562 - val_categorical_accuracy: 0.8820 - val_loss: 0.3310
# Epoch 15/100
# 311/311 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - categorical_accuracy: 0.9049 - loss: 0.2556 - val_categorical_accuracy: 0.8571 - val_loss: 0.4573
# Epoch 16/100
# 311/311 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - categorical_accuracy: 0.9065 - loss: 0.2521 - val_categorical_accuracy: 0.8805 - val_loss: 0.3259
# Epoch 17/100
# 311/311 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - categorical_accuracy: 0.9077 - loss: 0.2446 - val_categorical_accuracy: 0.8785 - val_loss: 0.3570
# Epoch 18/100
# 311/311 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - categorical_accuracy: 0.9104 - loss: 0.2368 - val_categorical_accuracy: 0.8751 - val_loss: 0.3805
# Epoch 19/100
# 311/311 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - categorical_accuracy: 0.9076 - loss: 0.2432 - val_categorical_accuracy: 0.8732 - val_loss: 0.3795
# Epoch 20/100
# 311/311 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - categorical_accuracy: 0.9072 - loss: 0.2355 - val_categorical_accuracy: 0.8628 - val_loss: 0.4614
# Epoch 21/100
# 311/311 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - categorical_accuracy: 0.9062 - loss: 0.2408 - val_categorical_accuracy: 0.8759 - val_loss: 0.3637
# Epoch 22/100
# 311/311 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - categorical_accuracy: 0.9077 - loss: 0.2333 - val_categorical_accuracy: 0.8931 - val_loss: 0.2962
# Epoch 23/100
# 311/311 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - categorical_accuracy: 0.9107 - loss: 0.2315 - val_categorical_accuracy: 0.8697 - val_loss: 0.4223
# Epoch 24/100
# 311/311 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - categorical_accuracy: 0.9102 - loss: 0.2294 - val_categorical_accuracy: 0.8885 - val_loss: 0.2943
# Epoch 25/100
# 311/311 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - categorical_accuracy: 0.9089 - loss: 0.2422 - val_categorical_accuracy: 0.8843 - val_loss: 0.3229
# Epoch 26/100
# 311/311 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - categorical_accuracy: 0.9091 - loss: 0.2343 - val_categorical_accuracy: 0.8881 - val_loss: 0.3013
# Epoch 27/100
# 311/311 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - categorical_accuracy: 0.9155 - loss: 0.2231 - val_categorical_accuracy: 0.8931 - val_loss: 0.2923
# Epoch 28/100
# 311/311 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - categorical_accuracy: 0.9122 - loss: 0.2251 - val_categorical_accuracy: 0.8732 - val_loss: 0.3405
# Epoch 29/100
# 311/311 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - categorical_accuracy: 0.9128 - loss: 0.2250 - val_categorical_accuracy: 0.8969 - val_loss: 0.2643
# Epoch 30/100
# 311/311 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - categorical_accuracy: 0.9130 - loss: 0.2268 - val_categorical_accuracy: 0.8789 - val_loss: 0.3491
# Epoch 31/100
# 311/311 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - categorical_accuracy: 0.9046 - loss: 0.2361 - val_categorical_accuracy: 0.8851 - val_loss: 0.3512
# Epoch 32/100
# 311/311 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - categorical_accuracy: 0.9066 - loss: 0.2341 - val_categorical_accuracy: 0.8831 - val_loss: 0.3173
# Epoch 33/100
# 311/311 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - categorical_accuracy: 0.9110 - loss: 0.2227 - val_categorical_accuracy: 0.8985 - val_loss: 0.2731
# Epoch 34/100
# 311/311 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - categorical_accuracy: 0.9104 - loss: 0.2255 - val_categorical_accuracy: 0.8950 - val_loss: 0.3051
# Epoch 35/100
# 311/311 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - categorical_accuracy: 0.9078 - loss: 0.2363 - val_categorical_accuracy: 0.8931 - val_loss: 0.2981
# Epoch 36/100
# 311/311 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - categorical_accuracy: 0.9138 - loss: 0.2210 - val_categorical_accuracy: 0.8996 - val_loss: 0.2743
# Epoch 37/100
# 311/311 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - categorical_accuracy: 0.9161 - loss: 0.2252 - val_categorical_accuracy: 0.8621 - val_loss: 0.3422
# Epoch 38/100
# 311/311 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - categorical_accuracy: 0.9127 - loss: 0.2216 - val_categorical_accuracy: 0.8904 - val_loss: 0.3175
# Epoch 39/100
# 311/311 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - categorical_accuracy: 0.9164 - loss: 0.2193 - val_categorical_accuracy: 0.8433 - val_loss: 0.5663
# Epoch 40/100
# 311/311 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - categorical_accuracy: 0.9136 - loss: 0.2218 - val_categorical_accuracy: 0.9004 - val_loss: 0.2731
# Epoch 41/100
# 311/311 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - categorical_accuracy: 0.9167 - loss: 0.2120 - val_categorical_accuracy: 0.8854 - val_loss: 0.3453
# Epoch 42/100
# 311/311 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - categorical_accuracy: 0.9100 - loss: 0.2259 - val_categorical_accuracy: 0.8897 - val_loss: 0.3014
# Epoch 43/100
# 311/311 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - categorical_accuracy: 0.9159 - loss: 0.2169 - val_categorical_accuracy: 0.8828 - val_loss: 0.2982
# Epoch 44/100
# 311/311 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - categorical_accuracy: 0.9120 - loss: 0.2200 - val_categorical_accuracy: 0.8908 - val_loss: 0.3108
# Epoch 45/100
# 311/311 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - categorical_accuracy: 0.9101 - loss: 0.2261 - val_categorical_accuracy: 0.9008 - val_loss: 0.2713
# Epoch 46/100
# 311/311 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - categorical_accuracy: 0.9226 - loss: 0.2049 - val_categorical_accuracy: 0.8950 - val_loss: 0.2996
# Epoch 47/100
# 311/311 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - categorical_accuracy: 0.9135 - loss: 0.2157 - val_categorical_accuracy: 0.8950 - val_loss: 0.2808
# Epoch 48/100
# 311/311 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - categorical_accuracy: 0.9178 - loss: 0.2156 - val_categorical_accuracy: 0.8889 - val_loss: 0.3285
# Epoch 49/100
# 311/311 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - categorical_accuracy: 0.9195 - loss: 0.2108 - val_categorical_accuracy: 0.8766 - val_loss: 0.3642
# Epoch 50/100
# 311/311 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - categorical_accuracy: 0.9131 - loss: 0.2287 - val_categorical_accuracy: 0.8912 - val_loss: 0.2993
# Epoch 51/100
# 311/311 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - categorical_accuracy: 0.9162 - loss: 0.2086 - val_categorical_accuracy: 0.8935 - val_loss: 0.3245
# Epoch 52/100
# 311/311 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - categorical_accuracy: 0.9143 - loss: 0.2137 - val_categorical_accuracy: 0.8870 - val_loss: 0.3404
# Epoch 53/100
# 311/311 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - categorical_accuracy: 0.9174 - loss: 0.2175 - val_categorical_accuracy: 0.9038 - val_loss: 0.2573
# Epoch 54/100
# 311/311 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - categorical_accuracy: 0.9153 - loss: 0.2141 - val_categorical_accuracy: 0.8893 - val_loss: 0.3216
# Epoch 55/100
# 311/311 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - categorical_accuracy: 0.9091 - loss: 0.2274 - val_categorical_accuracy: 0.8927 - val_loss: 0.3154
# Epoch 56/100
# 311/311 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - categorical_accuracy: 0.9171 - loss: 0.2135 - val_categorical_accuracy: 0.8950 - val_loss: 0.2915
# Epoch 57/100
# 311/311 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - categorical_accuracy: 0.9186 - loss: 0.2078 - val_categorical_accuracy: 0.8989 - val_loss: 0.2862
# Epoch 58/100
# 311/311 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - categorical_accuracy: 0.9210 - loss: 0.2087 - val_categorical_accuracy: 0.8897 - val_loss: 0.3368
# Epoch 59/100
# 311/311 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - categorical_accuracy: 0.9163 - loss: 0.2093 - val_categorical_accuracy: 0.8931 - val_loss: 0.3014
# Epoch 60/100
# 311/311 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - categorical_accuracy: 0.9119 - loss: 0.2240 - val_categorical_accuracy: 0.8808 - val_loss: 0.4054
# Epoch 61/100
# 311/311 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - categorical_accuracy: 0.9160 - loss: 0.2143 - val_categorical_accuracy: 0.9004 - val_loss: 0.2747
# Epoch 62/100
# 311/311 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - categorical_accuracy: 0.9227 - loss: 0.2015 - val_categorical_accuracy: 0.8985 - val_loss: 0.2839
# Epoch 63/100
# 311/311 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - categorical_accuracy: 0.9149 - loss: 0.2192 - val_categorical_accuracy: 0.9023 - val_loss: 0.2570
# Epoch 64/100
# 311/311 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - categorical_accuracy: 0.9172 - loss: 0.2111 - val_categorical_accuracy: 0.8977 - val_loss: 0.2858
# Epoch 65/100
# 311/311 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - categorical_accuracy: 0.9214 - loss: 0.2024 - val_categorical_accuracy: 0.8954 - val_loss: 0.2946
# Epoch 66/100
# 311/311 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - categorical_accuracy: 0.9152 - loss: 0.2202 - val_categorical_accuracy: 0.8916 - val_loss: 0.3135
# Epoch 67/100
# 311/311 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - categorical_accuracy: 0.9169 - loss: 0.2127 - val_categorical_accuracy: 0.8962 - val_loss: 0.2913
# Epoch 68/100
# 311/311 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - categorical_accuracy: 0.9171 - loss: 0.2070 - val_categorical_accuracy: 0.8962 - val_loss: 0.2905
# Epoch 69/100
# 311/311 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - categorical_accuracy: 0.9180 - loss: 0.2168 - val_categorical_accuracy: 0.9019 - val_loss: 0.2638
# Epoch 70/100
# 311/311 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - categorical_accuracy: 0.9179 - loss: 0.2108 - val_categorical_accuracy: 0.8421 - val_loss: 0.5314
# Epoch 71/100
# 311/311 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - categorical_accuracy: 0.9151 - loss: 0.2212 - val_categorical_accuracy: 0.9077 - val_loss: 0.2434
# Epoch 72/100
# 311/311 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - categorical_accuracy: 0.9220 - loss: 0.2027 - val_categorical_accuracy: 0.8920 - val_loss: 0.3319
# Epoch 73/100
# 311/311 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - categorical_accuracy: 0.9155 - loss: 0.2254 - val_categorical_accuracy: 0.8927 - val_loss: 0.3077
# Epoch 74/100
# 311/311 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - categorical_accuracy: 0.9249 - loss: 0.1942 - val_categorical_accuracy: 0.9000 - val_loss: 0.2826
# Epoch 75/100
# 311/311 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - categorical_accuracy: 0.9137 - loss: 0.2111 - val_categorical_accuracy: 0.8935 - val_loss: 0.3441
# Epoch 76/100
# 311/311 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - categorical_accuracy: 0.9158 - loss: 0.2210 - val_categorical_accuracy: 0.8812 - val_loss: 0.3914
# Epoch 77/100
# 311/311 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - categorical_accuracy: 0.9189 - loss: 0.2020 - val_categorical_accuracy: 0.8973 - val_loss: 0.2997
# Epoch 78/100
# 311/311 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - categorical_accuracy: 0.9203 - loss: 0.2069 - val_categorical_accuracy: 0.8762 - val_loss: 0.3969
# Epoch 79/100
# 311/311 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - categorical_accuracy: 0.9174 - loss: 0.2138 - val_categorical_accuracy: 0.8943 - val_loss: 0.3147
# Epoch 80/100
# 311/311 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - categorical_accuracy: 0.9150 - loss: 0.2134 - val_categorical_accuracy: 0.8943 - val_loss: 0.2967
# Epoch 81/100
# 311/311 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - categorical_accuracy: 0.9123 - loss: 0.2165 - val_categorical_accuracy: 0.8996 - val_loss: 0.2838
# Epoch 82/100
# 311/311 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - categorical_accuracy: 0.9154 - loss: 0.2203 - val_categorical_accuracy: 0.9015 - val_loss: 0.2853
# Epoch 83/100
# 311/311 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - categorical_accuracy: 0.9240 - loss: 0.1983 - val_categorical_accuracy: 0.8962 - val_loss: 0.3027
# Epoch 84/100
# 311/311 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - categorical_accuracy: 0.9148 - loss: 0.2146 - val_categorical_accuracy: 0.8805 - val_loss: 0.4270
# Epoch 85/100
# 311/311 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - categorical_accuracy: 0.9134 - loss: 0.2110 - val_categorical_accuracy: 0.8992 - val_loss: 0.2935
# Epoch 86/100
# 311/311 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - categorical_accuracy: 0.9168 - loss: 0.2115 - val_categorical_accuracy: 0.8958 - val_loss: 0.2703
# Epoch 87/100
# 311/311 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - categorical_accuracy: 0.9254 - loss: 0.1920 - val_categorical_accuracy: 0.8858 - val_loss: 0.3577
# Epoch 88/100
# 311/311 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - categorical_accuracy: 0.9209 - loss: 0.1999 - val_categorical_accuracy: 0.9023 - val_loss: 0.2565
# Epoch 89/100
# 311/311 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - categorical_accuracy: 0.9200 - loss: 0.2059 - val_categorical_accuracy: 0.9031 - val_loss: 0.2609
# Epoch 90/100
# 311/311 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - categorical_accuracy: 0.9148 - loss: 0.2142 - val_categorical_accuracy: 0.8728 - val_loss: 0.5231
# Epoch 91/100
# ...
# /var/folders/qg/czgp8gyn3057jghb1vm_44yr0000gp/T/ipykernel_10232/3521911706.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_fold_val[columns_to_normalize] = scaler.fit_transform(X_fold_val[columns_to_normalize])
# Epoch 1/100
# 315/315 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - categorical_accuracy: 0.5188 - loss: 1.2655 - val_categorical_accuracy: 0.7819 - val_loss: 0.6020
# Epoch 2/100
# 315/315 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - categorical_accuracy: 0.8398 - loss: 0.4691 - val_categorical_accuracy: 0.8610 - val_loss: 0.3776
# Epoch 3/100
# 315/315 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - categorical_accuracy: 0.8648 - loss: 0.4053 - val_categorical_accuracy: 0.8000 - val_loss: 0.5665
# Epoch 4/100
# 315/315 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - categorical_accuracy: 0.8733 - loss: 0.3631 - val_categorical_accuracy: 0.7707 - val_loss: 0.9213
# Epoch 5/100
# 315/315 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - categorical_accuracy: 0.8811 - loss: 0.3447 - val_categorical_accuracy: 0.8474 - val_loss: 0.4405
# Epoch 6/100
# 315/315 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - categorical_accuracy: 0.8825 - loss: 0.3284 - val_categorical_accuracy: 0.8004 - val_loss: 0.7477
# Epoch 7/100
# 315/315 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - categorical_accuracy: 0.8960 - loss: 0.3023 - val_categorical_accuracy: 0.7992 - val_loss: 0.7011
# Epoch 8/100
# 315/315 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - categorical_accuracy: 0.8958 - loss: 0.3016 - val_categorical_accuracy: 0.8209 - val_loss: 0.5541
# Epoch 9/100
# 315/315 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - categorical_accuracy: 0.8904 - loss: 0.2971 - val_categorical_accuracy: 0.8197 - val_loss: 0.5641
# Epoch 10/100
# 315/315 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - categorical_accuracy: 0.8929 - loss: 0.3061 - val_categorical_accuracy: 0.8108 - val_loss: 0.6184
# Epoch 11/100
# 315/315 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - categorical_accuracy: 0.8964 - loss: 0.2831 - val_categorical_accuracy: 0.7811 - val_loss: 0.8777
# Epoch 12/100
# 315/315 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - categorical_accuracy: 0.9041 - loss: 0.2732 - val_categorical_accuracy: 0.7904 - val_loss: 0.7744
# Epoch 13/100
# 315/315 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - categorical_accuracy: 0.9023 - loss: 0.2683 - val_categorical_accuracy: 0.8112 - val_loss: 0.6786
# Epoch 14/100
# 315/315 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - categorical_accuracy: 0.9040 - loss: 0.2634 - val_categorical_accuracy: 0.8486 - val_loss: 0.5252
# Epoch 15/100
# 315/315 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - categorical_accuracy: 0.8950 - loss: 0.2781 - val_categorical_accuracy: 0.8655 - val_loss: 0.4076
# Epoch 16/100
# 315/315 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - categorical_accuracy: 0.8980 - loss: 0.2789 - val_categorical_accuracy: 0.7936 - val_loss: 0.8241
# Epoch 17/100
# 315/315 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - categorical_accuracy: 0.9014 - loss: 0.2676 - val_categorical_accuracy: 0.7771 - val_loss: 0.7569
# Epoch 18/100
# 315/315 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - categorical_accuracy: 0.9007 - loss: 0.2633 - val_categorical_accuracy: 0.7795 - val_loss: 1.1913
# Epoch 19/100
# 315/315 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - categorical_accuracy: 0.9047 - loss: 0.2575 - val_categorical_accuracy: 0.7643 - val_loss: 1.0874
# Epoch 20/100
# 315/315 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - categorical_accuracy: 0.9074 - loss: 0.2442 - val_categorical_accuracy: 0.8084 - val_loss: 0.8448
# Epoch 21/100
# 315/315 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - categorical_accuracy: 0.9065 - loss: 0.2432 - val_categorical_accuracy: 0.8141 - val_loss: 0.9345
# Epoch 22/100
# 315/315 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - categorical_accuracy: 0.9030 - loss: 0.2534 - val_categorical_accuracy: 0.8265 - val_loss: 0.7122
# Epoch 23/100
# 315/315 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - categorical_accuracy: 0.9046 - loss: 0.2486 - val_categorical_accuracy: 0.8185 - val_loss: 0.5746
# Epoch 24/100
# 315/315 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - categorical_accuracy: 0.9062 - loss: 0.2479 - val_categorical_accuracy: 0.8337 - val_loss: 0.4553
# Epoch 25/100
# 315/315 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - categorical_accuracy: 0.9071 - loss: 0.2389 - val_categorical_accuracy: 0.8309 - val_loss: 0.5090
# Epoch 26/100
# 315/315 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - categorical_accuracy: 0.9071 - loss: 0.2425 - val_categorical_accuracy: 0.7936 - val_loss: 0.9379
# Epoch 27/100
# 315/315 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - categorical_accuracy: 0.9142 - loss: 0.2253 - val_categorical_accuracy: 0.8406 - val_loss: 0.4163
# Epoch 28/100
# 315/315 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - categorical_accuracy: 0.9105 - loss: 0.2323 - val_categorical_accuracy: 0.8016 - val_loss: 0.7580
# Epoch 29/100
# 315/315 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - categorical_accuracy: 0.9040 - loss: 0.2486 - val_categorical_accuracy: 0.8486 - val_loss: 0.4918
# Epoch 30/100
# 315/315 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - categorical_accuracy: 0.9070 - loss: 0.2396 - val_categorical_accuracy: 0.7767 - val_loss: 1.3282
# Epoch 31/100
# 315/315 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - categorical_accuracy: 0.9103 - loss: 0.2361 - val_categorical_accuracy: 0.8839 - val_loss: 0.3298
# Epoch 32/100
# 315/315 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - categorical_accuracy: 0.9086 - loss: 0.2411 - val_categorical_accuracy: 0.8197 - val_loss: 0.4923
# Epoch 33/100
# 315/315 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - categorical_accuracy: 0.9104 - loss: 0.2317 - val_categorical_accuracy: 0.8257 - val_loss: 0.6161
# Epoch 34/100
# 315/315 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - categorical_accuracy: 0.9132 - loss: 0.2213 - val_categorical_accuracy: 0.8213 - val_loss: 0.8819
# Epoch 35/100
# 315/315 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - categorical_accuracy: 0.9114 - loss: 0.2314 - val_categorical_accuracy: 0.8671 - val_loss: 0.3453
# Epoch 36/100
# 315/315 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - categorical_accuracy: 0.9146 - loss: 0.2200 - val_categorical_accuracy: 0.8084 - val_loss: 0.6916
# Epoch 37/100
# 315/315 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - categorical_accuracy: 0.9042 - loss: 0.2446 - val_categorical_accuracy: 0.8185 - val_loss: 0.5788
# Epoch 38/100
# 315/315 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - categorical_accuracy: 0.9101 - loss: 0.2285 - val_categorical_accuracy: 0.8092 - val_loss: 0.7841
# Epoch 39/100
# 315/315 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - categorical_accuracy: 0.9087 - loss: 0.2259 - val_categorical_accuracy: 0.8293 - val_loss: 0.5487
# Epoch 40/100
# 315/315 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - categorical_accuracy: 0.9087 - loss: 0.2326 - val_categorical_accuracy: 0.8145 - val_loss: 0.7998
# Epoch 41/100
# 315/315 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - categorical_accuracy: 0.9123 - loss: 0.2235 - val_categorical_accuracy: 0.7920 - val_loss: 1.4782
# Epoch 42/100
# 315/315 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - categorical_accuracy: 0.9144 - loss: 0.2290 - val_categorical_accuracy: 0.8229 - val_loss: 0.6877
# Epoch 43/100
# 315/315 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - categorical_accuracy: 0.9144 - loss: 0.2311 - val_categorical_accuracy: 0.8337 - val_loss: 0.5617
# Epoch 44/100
# 315/315 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - categorical_accuracy: 0.9110 - loss: 0.2283 - val_categorical_accuracy: 0.8201 - val_loss: 0.7470
# Epoch 45/100
# 315/315 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - categorical_accuracy: 0.9118 - loss: 0.2315 - val_categorical_accuracy: 0.8747 - val_loss: 0.3782
# Epoch 46/100
# 315/315 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - categorical_accuracy: 0.9145 - loss: 0.2218 - val_categorical_accuracy: 0.8542 - val_loss: 0.5256
# Epoch 47/100
# 315/315 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - categorical_accuracy: 0.9145 - loss: 0.2169 - val_categorical_accuracy: 0.8297 - val_loss: 0.5736
# Epoch 48/100
# 315/315 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - categorical_accuracy: 0.9121 - loss: 0.2250 - val_categorical_accuracy: 0.7815 - val_loss: 0.9474
# Epoch 49/100
# 315/315 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - categorical_accuracy: 0.9190 - loss: 0.2177 - val_categorical_accuracy: 0.8715 - val_loss: 0.3813
# Epoch 50/100
# 315/315 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - categorical_accuracy: 0.9153 - loss: 0.2185 - val_categorical_accuracy: 0.8578 - val_loss: 0.4440
# Epoch 51/100
# 315/315 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - categorical_accuracy: 0.9163 - loss: 0.2172 - val_categorical_accuracy: 0.8534 - val_loss: 0.4325
# Epoch 52/100
# 315/315 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - categorical_accuracy: 0.9112 - loss: 0.2260 - val_categorical_accuracy: 0.8088 - val_loss: 0.6084
# Epoch 53/100
# 315/315 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - categorical_accuracy: 0.9150 - loss: 0.2126 - val_categorical_accuracy: 0.8329 - val_loss: 0.5385
# Epoch 54/100
# 315/315 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - categorical_accuracy: 0.9124 - loss: 0.2197 - val_categorical_accuracy: 0.8570 - val_loss: 0.5216
# Epoch 55/100
# 315/315 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - categorical_accuracy: 0.9206 - loss: 0.2090 - val_categorical_accuracy: 0.8478 - val_loss: 0.4953
# Epoch 56/100
# 315/315 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - categorical_accuracy: 0.9106 - loss: 0.2340 - val_categorical_accuracy: 0.8558 - val_loss: 0.4272
# Epoch 57/100
# 315/315 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - categorical_accuracy: 0.9084 - loss: 0.2312 - val_categorical_accuracy: 0.8064 - val_loss: 1.1526
# Epoch 58/100
# 315/315 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - categorical_accuracy: 0.9150 - loss: 0.2207 - val_categorical_accuracy: 0.8345 - val_loss: 0.6271
# Epoch 59/100
# 315/315 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - categorical_accuracy: 0.9166 - loss: 0.2132 - val_categorical_accuracy: 0.8076 - val_loss: 0.8437
# Epoch 60/100
# 315/315 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - categorical_accuracy: 0.9131 - loss: 0.2281 - val_categorical_accuracy: 0.8241 - val_loss: 0.6570
# Epoch 61/100
# 315/315 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - categorical_accuracy: 0.9154 - loss: 0.2160 - val_categorical_accuracy: 0.8635 - val_loss: 0.4022
# Epoch 62/100
# 315/315 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - categorical_accuracy: 0.9194 - loss: 0.2137 - val_categorical_accuracy: 0.8715 - val_loss: 0.3872
# Epoch 63/100
# 315/315 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - categorical_accuracy: 0.9083 - loss: 0.2390 - val_categorical_accuracy: 0.8787 - val_loss: 0.3306
# Epoch 64/100
# 315/315 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - categorical_accuracy: 0.9172 - loss: 0.2118 - val_categorical_accuracy: 0.8458 - val_loss: 0.4236
# Epoch 65/100
# 315/315 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - categorical_accuracy: 0.9145 - loss: 0.2275 - val_categorical_accuracy: 0.8888 - val_loss: 0.3304
# Epoch 66/100
# 315/315 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - categorical_accuracy: 0.9135 - loss: 0.2259 - val_categorical_accuracy: 0.8651 - val_loss: 0.4000
# Epoch 67/100
# 315/315 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - categorical_accuracy: 0.9176 - loss: 0.2126 - val_categorical_accuracy: 0.8747 - val_loss: 0.3472
# Epoch 68/100
# 315/315 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - categorical_accuracy: 0.9208 - loss: 0.2087 - val_categorical_accuracy: 0.8791 - val_loss: 0.3974
# Epoch 69/100
# 315/315 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - categorical_accuracy: 0.9160 - loss: 0.2132 - val_categorical_accuracy: 0.8185 - val_loss: 0.6164
# Epoch 70/100
# 315/315 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - categorical_accuracy: 0.9117 - loss: 0.2243 - val_categorical_accuracy: 0.8651 - val_loss: 0.3864
# Epoch 71/100
# 315/315 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - categorical_accuracy: 0.9080 - loss: 0.2271 - val_categorical_accuracy: 0.8598 - val_loss: 0.3827
# Epoch 72/100
# 315/315 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - categorical_accuracy: 0.9105 - loss: 0.2286 - val_categorical_accuracy: 0.9008 - val_loss: 0.2829
# Epoch 73/100
# 315/315 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - categorical_accuracy: 0.9185 - loss: 0.2169 - val_categorical_accuracy: 0.8482 - val_loss: 0.5029
# Epoch 74/100
# 315/315 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - categorical_accuracy: 0.9178 - loss: 0.2162 - val_categorical_accuracy: 0.8831 - val_loss: 0.3648
# Epoch 75/100
# 315/315 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - categorical_accuracy: 0.9184 - loss: 0.2076 - val_categorical_accuracy: 0.8618 - val_loss: 0.3843
# Epoch 76/100
# 315/315 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - categorical_accuracy: 0.9190 - loss: 0.2120 - val_categorical_accuracy: 0.8586 - val_loss: 0.4866
# Epoch 77/100
# 315/315 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - categorical_accuracy: 0.9140 - loss: 0.2156 - val_categorical_accuracy: 0.8361 - val_loss: 0.4161
# Epoch 78/100
# 315/315 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - categorical_accuracy: 0.9159 - loss: 0.2179 - val_categorical_accuracy: 0.8779 - val_loss: 0.4188
# Epoch 79/100
# 315/315 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - categorical_accuracy: 0.9144 - loss: 0.2244 - val_categorical_accuracy: 0.8767 - val_loss: 0.3857
# Epoch 80/100
# 315/315 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - categorical_accuracy: 0.9199 - loss: 0.2062 - val_categorical_accuracy: 0.8221 - val_loss: 0.6440
# Epoch 81/100
# 315/315 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - categorical_accuracy: 0.9114 - loss: 0.2250 - val_categorical_accuracy: 0.8667 - val_loss: 0.4334
# Epoch 82/100
# 315/315 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - categorical_accuracy: 0.9124 - loss: 0.2223 - val_categorical_accuracy: 0.8281 - val_loss: 0.6719
# Epoch 83/100
# 315/315 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - categorical_accuracy: 0.9138 - loss: 0.2154 - val_categorical_accuracy: 0.8586 - val_loss: 0.5915
# Epoch 84/100
# 315/315 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - categorical_accuracy: 0.9154 - loss: 0.2191 - val_categorical_accuracy: 0.8189 - val_loss: 1.1565
# Epoch 85/100
# 315/315 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - categorical_accuracy: 0.9141 - loss: 0.2200 - val_categorical_accuracy: 0.8659 - val_loss: 0.5313
# Epoch 86/100
# 315/315 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - categorical_accuracy: 0.9144 - loss: 0.2225 - val_categorical_accuracy: 0.8382 - val_loss: 0.6784
# Epoch 87/100
# 315/315 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - categorical_accuracy: 0.9156 - loss: 0.2124 - val_categorical_accuracy: 0.8590 - val_loss: 0.6538
# Epoch 88/100
# 315/315 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - categorical_accuracy: 0.9148 - loss: 0.2111 - val_categorical_accuracy: 0.8494 - val_loss: 0.7437
# Epoch 89/100
# 315/315 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - categorical_accuracy: 0.9146 - loss: 0.2147 - val_categorical_accuracy: 0.8647 - val_loss: 0.6669
# Epoch 90/100
# 315/315 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - categorical_accuracy: 0.9206 - loss: 0.2025 - val_categorical_accuracy: 0.8313 - val_loss: 0.9355
# Epoch 91/100
# 315/315 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - categorical_accuracy: 0.9115 - loss: 0.2233 - val_categorical_accuracy: 0.8353 - val_loss: 0.7980
# Epoch 92/100
# 315/315 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - categorical_accuracy: 0.9167 - loss: 0.2209 - val_categorical_accuracy: 0.8743 - val_loss: 0.5039
# Epoch 93/100
# 315/315 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - categorical_accuracy: 0.9186 - loss: 0.2084 - val_categorical_accuracy: 0.8904 - val_loss: 0.3614
# Epoch 94/100
# 315/315 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - categorical_accuracy: 0.9163 - loss: 0.2178 - val_categorical_accuracy: 0.8651 - val_loss: 0.5391
# Epoch 95/100
# 315/315 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - categorical_accuracy: 0.9125 - loss: 0.2142 - val_categorical_accuracy: 0.8594 - val_loss: 0.6556
# Epoch 96/100
# 315/315 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - categorical_accuracy: 0.9171 - loss: 0.2176 - val_categorical_accuracy: 0.8546 - val_loss: 0.5000
# Epoch 97/100
# 315/315 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - categorical_accuracy: 0.9170 - loss: 0.2110 - val_categorical_accuracy: 0.8261 - val_loss: 1.0640
# Epoch 98/100
# 315/315 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - categorical_accuracy: 0.9217 - loss: 0.2003 - val_categorical_accuracy: 0.8044 - val_loss: 0.9181
# Epoch 99/100
# 315/315 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - categorical_accuracy: 0.9194 - loss: 0.2111 - val_categorical_accuracy: 0.8699 - val_loss: 0.3515
# Epoch 100/100
# 315/315 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - categorical_accuracy: 0.9125 - loss: 0.2255 - val_categorical_accuracy: 0.8538 - val_loss: 0.4413
# 17588/17588 ━━━━━━━━━━━━━━━━━━━━ 14s 780us/step

# %%
metric_names = list(histories[0].history.keys())
avg_metrics = {metric: [] for metric in metric_names}

# Compute mean per epoch across folds
for metric in metric_names:
    avg_metrics[metric] = np.mean([fold.history[metric] for fold in histories], axis=0)

# Print average metrics
for metric, values in avg_metrics.items():
    print(f"Average {metric}: {values[-1]:.4f}")  # Showing the last epoch's value
# Out:
# Average categorical_accuracy: 0.9173
# Average loss: 0.2099
# Average val_categorical_accuracy: 0.8992
# Average val_loss: 0.2981

# %%
threshold = 0.5
avg_predictions = np.mean(predictions, axis=0)  # Mean ensemble
y_pred_binary = (avg_predictions >= threshold).astype(int)

# %%
print(classification_report(y_test_binary, y_pred_binary, zero_division=0, digits=4))
# Out:
#               precision    recall  f1-score   support
#
#            0     0.9996    0.8329    0.9086    365427
#            1     0.9972    0.9993    0.9982     47234
#            2     0.3142    0.9544    0.4727      3863
#            3     0.9359    0.6254    0.7498    141203
#            4     0.7141    0.7835    0.7472      2739
#            5     0.6451    0.7999    0.7142      2334
#
#    micro avg     0.9650    0.7953    0.8719    562800
#    macro avg     0.7677    0.8326    0.7651    562800
# weighted avg     0.9758    0.7953    0.8717    562800
#  samples avg     0.7953    0.7953    0.7953    562800

# %%
# Plot loss and accuraccy of training

# Plot accuracy
plt.plot(avg_metrics['categorical_accuracy'], label='Training Accuracy')
plt.plot(avg_metrics['val_categorical_accuracy'], label='Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.title('Training and Validation Accuracy')
plt.show()

# Plot loss
plt.plot(avg_metrics['loss'], label='Training Loss')
plt.plot(avg_metrics['val_loss'], label='Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.title('Training and Validation Loss')
plt.show()

# %%
# Compute multilabel confusion matrix
mcm = multilabel_confusion_matrix(y_test_binary, y_pred_binary)

attack_labels = ["Benign", "DDoS_LOIT", "DoS_GoldenEye", "DoS_Hulk", "DoS_Slowhttptest", "DoS_Slowloris"]

# Set up the plot
fig, axes = plt.subplots(2, 3, figsize=(12, 8))

# Plot each confusion matrix as a heatmap
for i, ax in enumerate(axes.flat):
    cm = mcm[i]
    
    # Calculate percentages
    cm_percent = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis] * 100  # Normalize by row (True Labels)
    
    # Annotate with both raw count and percentage
    annotations = []
    for j in range(cm.shape[0]):  # Loop through each row
        row_annotations = []
        for k in range(cm.shape[1]):  # Loop through each column
            count = cm[j, k]
            percentage = cm_percent[j, k]
            row_annotations.append(f'{count}\n({percentage:.2f}%)')
        annotations.append(row_annotations)
    
    # Plot the confusion matrix with both numbers and percentages
    sns.heatmap(cm_percent, annot=annotations, fmt='', cmap='Blues', cbar=False, ax=ax, 
                annot_kws={"size": 10}, xticklabels=['Negative', 'Positive'], yticklabels=['Negative', 'Positive'])
    
    ax.set_title(f'Confusion Matrix {attack_labels[i]}')
    ax.set_xlabel('Predicted Labels')
    ax.set_ylabel('True Labels')

plt.tight_layout()
plt.show()

# %%
# Compute micro-average ROC curve and AUC
fpr, tpr, _ = roc_curve(y_test_binary.ravel(), y_pred_binary.ravel())
roc_auc = auc(fpr, tpr)

# Plot the ROC curve
plt.figure(figsize=(8, 6))
plt.plot(fpr, tpr, label=f'AUC = {roc_auc:.2f}')

# Plot random classifier
# plt.plot([0, 1], [0, 1], 'k--', label='Random (AUC = 0.50)')

# Formatting
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('LSTM Batch learning ROC AUC Score')
plt.legend()
plt.grid()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import confusion_matrix

# Convert one-hot to class indices
y_true = np.argmax(y_test_binary, axis=1)
y_pred = np.argmax(y_pred_binary, axis=1)

# Compute confusion matrix
cm = confusion_matrix(y_true, y_pred)
row_totals = cm.sum(axis=1)
cm_percent = cm.astype('float') / row_totals[:, np.newaxis] * 100

# Add a new column with zeros for the "Total" column (for coloring)
cm_percent_extended = np.hstack([cm_percent, np.zeros((cm_percent.shape[0], 1))])

# Create extended annotations with Total
annotations = np.empty_like(cm_percent_extended).astype(str)
for i in range(cm.shape[0]):
    for j in range(cm.shape[1]):
        count = cm[i, j]
        percent = cm_percent[i, j]
        annotations[i, j] = f"{percent:.2f}%\n{count}"
    # Add total count annotation to last column
    annotations[i, -1] = f"{row_totals[i]}"

# Updated labels
attack_labels = ["Benign", "DDoS_LOIT", "DoS_GoldenEye", "DoS_Hulk", "DoS_Slowhttptest", "DoS_Slowloris"]
xtick_labels = attack_labels + ["Total"]

# Set up the plot
plt.figure(figsize=(11, 8))  # Slightly wider for the extra column

# Use matching light cyan/blue color map
cmap = sns.light_palette("cadetblue", as_cmap=True)

# Plot heatmap
sns.heatmap(cm_percent_extended, annot=annotations, fmt='', cmap=cmap, cbar=False,
            xticklabels=xtick_labels, yticklabels=attack_labels,
            annot_kws={"size": 10, "color": "black"})

# Formatting
plt.xticks(rotation=30, ha='right', fontsize=10)
plt.yticks(rotation=0, fontsize=10)
plt.xlabel('Predicted Label', fontsize=12)
plt.ylabel('True Label', fontsize=12)
plt.title('Confusion Matrix', fontsize=14)
plt.tight_layout()
plt.show()
