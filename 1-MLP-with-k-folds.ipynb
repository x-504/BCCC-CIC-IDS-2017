# %%
import os
import numpy as np
import pandas as pd


import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout, Input, Flatten
from sklearn.model_selection import StratifiedKFold, KFold
from sklearn.pipeline import Pipeline
from tensorflow.keras.metrics import AUC
from sklearn.preprocessing import LabelEncoder, StandardScaler, MinMaxScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, accuracy_score
from sklearn.preprocessing import MultiLabelBinarizer
from sklearn.metrics import multilabel_confusion_matrix
from imblearn.under_sampling import RandomUnderSampler
from keras.optimizers import Adam

from keras.callbacks import ModelCheckpoint
from keras.models import load_model



import matplotlib.pyplot as plt
from sklearn.metrics import roc_curve, auc, RocCurveDisplay
import seaborn as sns
from itertools import cycle

# %%
# Define defaults

# Set seed for NumPy
np.random.seed(42)

FILENAME = "../../datasets/BCCC-CIC-IDS-2017/subsets/training_v1.csv"
FILENAME_TEST = "../../datasets/BCCC-CIC-IDS-2017/subsets/test_v1.csv"

# %%
# Load csv file
df = pd.read_csv(FILENAME, low_memory=False)
df_test = pd.read_csv(FILENAME_TEST, low_memory=False)

# %%
X_train = df.drop("label", axis=1)
y_train = df["label"]


X_test = df_test.drop("label", axis=1)
y_test = df_test["label"]

# %%
X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size=0.1)

# %%
y_train.value_counts()
# Out:
# label
# 0    328438
# 3    127418
# 1     42573
# 2      3460
# 4      2537
# 5      2093
# Name: count, dtype: int64

# %%
y_train.shape
# Out:
# (506519,)

# %%
y_test.value_counts()
# Out:
# label
# 0    365427
# 3    141203
# 1     47234
# 2      3863
# 4      2739
# 5      2334
# Name: count, dtype: int64

# %%
y_test.shape
# Out:
# (562800,)

# %%
# Prepration for Normalize features
scaler = MinMaxScaler(feature_range=(0, 1))
columns_to_normalize = X_train.columns.tolist()

# %%
columns_to_normalize
# Out:
# ['fwd_rst_flag_counts',
#  'rst_flag_counts',
#  'bwd_avg_segment_size',
#  'bwd_payload_bytes_variance',
#  'payload_bytes_std',
#  'bwd_payload_bytes_std',
#  'fwd_payload_bytes_std',
#  'payload_bytes_variance',
#  'payload_bytes_mean',
#  'fwd_payload_bytes_mean',
#  'bwd_payload_bytes_mean',
#  'avg_segment_size',
#  'payload_bytes_max',
#  'fwd_payload_bytes_max',
#  'bwd_payload_bytes_max',
#  'packet_IAT_min',
#  'packets_IAT_mean',
#  'packet_IAT_max',
#  'packet_IAT_total',
#  'fwd_packets_IAT_min',
#  'fwd_packets_IAT_mean',
#  'fwd_packets_IAT_total',
#  'fwd_packets_IAT_max',
#  'bwd_std_header_bytes',
#  'active_std',
#  'idle_min',
#  'idle_mean',
#  'idle_max',
#  'bwd_rst_flag_counts',
#  'fwd_std_header_bytes',
#  'std_header_bytes',
#  'fwd_syn_flag_counts',
#  'bwd_init_win_bytes',
#  'bwd_fin_flag_counts',
#  'fwd_packets_IAT_std',
#  'fwd_init_win_bytes',
#  'bwd_packets_IAT_min',
#  'bwd_packets_IAT_mean',
#  'bwd_packets_IAT_max',
#  'bwd_packets_IAT_total',
#  'bwd_max_header_bytes',
#  'packet_IAT_std',
#  'syn_flag_counts',
#  'bwd_bytes_rate',
#  'min_header_bytes',
#  'fwd_bulk_duration',
#  'bwd_mean_header_bytes',
#  'bwd_min_header_bytes',
#  'avg_bwd_bulk_rate',
#  'mean_header_bytes',
#  'bytes_rate',
#  'fwd_fin_flag_counts',
#  'bwd_packets_IAT_std',
#  'fwd_min_header_bytes',
#  'bwd_syn_flag_counts',
#  'duration',
#  'fwd_mean_header_bytes',
#  'avg_fwd_packets_per_bulk',
#  'fin_flag_counts',
#  'fwd_max_header_bytes',
#  'fwd_avg_segment_size',
#  'max_header_bytes',
#  'bwd_payload_bytes_min',
#  'fwd_payload_bytes_min',
#  'payload_bytes_min',
#  'idle_std',
#  'down_up_rate',
#  'fwd_ece_flag_counts',
#  'ece_flag_counts',
#  'bwd_ece_flag_counts',
#  'fwd_payload_bytes_variance',
#  'fwd_bulk_state_count',
#  'fwd_psh_flag_counts',
#  'fwd_packets_rate',
#  'fwd_bulk_per_packet',
#  'fwd_bytes_rate',
#  'avg_fwd_bytes_per_bulk',
#  'avg_bwd_packets_bulk_rate',
#  'packets_rate',
#  'subflow_bwd_bytes',
#  'subflow_fwd_bytes',
#  'fwd_total_payload_bytes',
#  'avg_bwd_bytes_per_bulk',
#  'psh_flag_counts',
#  'bwd_psh_flag_counts',
#  'bwd_packets_rate',
#  'bwd_bulk_duration',
#  'cwr_flag_counts',
#  'fwd_cwr_flag_counts',
#  'fwd_bulk_total_size',
#  'bwd_bulk_state_count',
#  'avg_fwd_bulk_rate',
#  'bwd_total_header_bytes',
#  'bwd_ack_flag_counts',
#  'bwd_packets_count',
#  'ack_flag_counts',
#  'packets_count',
#  'total_header_bytes',
#  'fwd_ack_flag_counts',
#  'fwd_packets_count',
#  'fwd_total_header_bytes',
#  'bwd_bulk_per_packet',
#  'total_payload_bytes',
#  'bwd_total_payload_bytes',
#  'bwd_bulk_total_size',
#  'bwd_cwr_flag_counts',
#  'subflow_fwd_packets',
#  'subflow_bwd_packets']

# %%
# Configuration for Cross Validation
kf = KFold(n_splits=5)
rus = RandomUnderSampler(random_state=42, sampling_strategy='auto')
seq_length = 1  # Number of time steps per sequence
mlb = MultiLabelBinarizer(classes=range(6))  # Specify the classes if needed (in this case, 6 labels)
histories = []
predictions = []

# %%
# ## Convert data into mlp-friendly format
X_test = X_test.to_numpy().reshape((X_test.shape[0], 1, X_test.shape[1]))
y_test_binary = mlb.fit_transform(y_test.to_numpy().reshape(-1, 1))

# %%
for i, (train_index, val_index) in enumerate(kf.split(X_train, y_train)):
    print(f"Fold {i + 1}:")
    print(f"  Train: index={train_index}")
    print(f"  Val:  index={val_index}")
    
    
    lstm = Sequential([
    Input(shape=(1, len(columns_to_normalize))),  # Now (timesteps=1, features)
    Flatten(),
    Dense(140, activation="relu", kernel_initializer='lecun_uniform'),
    Dense(120, activation="relu", kernel_initializer='lecun_uniform'),
    Dense(100, activation="relu", kernel_initializer='lecun_uniform'),
    Dense(80, activation="relu", kernel_initializer='lecun_uniform'),
    Dense(60, activation="relu", kernel_initializer='lecun_uniform'),
    Dense(40, activation="relu", kernel_initializer='lecun_uniform'),
    Dense(20, activation="relu", kernel_initializer='lecun_uniform'),
    Dense(120, activation="relu", kernel_initializer='lecun_uniform'),
    Dense(6, activation="softmax", kernel_initializer='glorot_uniform')
    ])

    # Compile the model
    optimizer = Adam(learning_rate=0.001)
    lstm.compile(optimizer="adam", loss="categorical_crossentropy", metrics=['categorical_accuracy'])
        
    # training
    X_fold_training = X_train.iloc[train_index]
    y_fold_training = y_train.iloc[train_index]
    
    # Normalize
    X_fold_training[columns_to_normalize] = scaler.fit_transform(X_fold_training[columns_to_normalize])
    
    # RUS
    X_fold_training, y_fold_training = rus.fit_resample(X_fold_training, y_fold_training)
    

    # print(f"Label distribution Training:\n")
    # print(y_fold_training.value_counts())
    
    # validation
    X_fold_val = X_train.iloc[val_index]
    y_fold_val = y_train.iloc[val_index]
    
    # Normalize
    X_fold_val[columns_to_normalize] = scaler.fit_transform(X_fold_val[columns_to_normalize])
    
    # RUS
    X_fold_val, y_fold_val = rus.fit_resample(X_fold_val, y_fold_val)
    
    
    # print(f"\nLabel distribution Validation:\n")
    # print(y_fold_val.value_counts())
    
    
    # Convert data into LSTM-friendly format
    X_train_lstm, y_train_lstm = [], []
    X_val_lstm, y_val_lstm = [], []
    
    # training
    X_train_lstm = X_fold_training.to_numpy().reshape((X_fold_training.shape[0], 1, X_fold_training.shape[1]))
    # for i in range(len(X_fold_training) - seq_length):
    #     X_train_lstm.append(X_fold_training[i : i + seq_length])
    #     y_train_lstm.append(y_fold_training.iloc[i + seq_length])
    
    # validation
    X_val_lstm = X_fold_val.to_numpy().reshape((X_fold_val.shape[0], 1, X_fold_val.shape[1]))
    # for i in range(len(X_fold_val) - seq_length):
    #     X_val_lstm.append(X_fold_val[i : i + seq_length])
    #     y_val_lstm.append(y_fold_val.iloc[i + seq_length])
    
    # X_train_lstm, y_train_lstm = np.array(X_train_lstm), np.array(y_train_lstm)
    # X_val_lstm, y_val_lstm = np.array(X_val_lstm), np.array(y_val_lstm)
    
    # Convert y_train, y_test and y_val to MultiLabel binaries
    y_train_binary = mlb.fit_transform(y_fold_training.to_numpy().reshape(-1, 1))
    y_val_binary = mlb.fit_transform(y_fold_val.to_numpy().reshape(-1, 1))
    
    # y_train_binary = mlb.fit_transform(y_train_lstm.reshape(-1, 1))
    # y_val_binary = mlb.fit_transform(y_val_lstm.reshape(-1, 1))
    
    # Train Model
    history = lstm.fit(X_train_lstm, y_train_binary, epochs=100, batch_size=32, validation_data=(X_val_lstm, y_val_binary))
    histories.append(history)
    
    # Classify using the Test dataset
    y_pred = (lstm.predict(X_test) > 0.5).astype("int32")
    predictions.append(y_pred)
    
    # print(classification_report(y_test_binary, y_pred, zero_division=0))
    # print(f"Accuracy: {accuracy_score(y_test_binary, y_pred):.4f}")
# Out:
# Fold 1:
#   Train: index=[101304 101305 101306 ... 506516 506517 506518]
#   Val:  index=[     0      1      2 ... 101301 101302 101303]
# /var/folders/qg/czgp8gyn3057jghb1vm_44yr0000gp/T/ipykernel_27255/140643231.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_fold_training[columns_to_normalize] = scaler.fit_transform(X_fold_training[columns_to_normalize])
# Epoch 1/100
# /var/folders/qg/czgp8gyn3057jghb1vm_44yr0000gp/T/ipykernel_27255/140643231.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_fold_val[columns_to_normalize] = scaler.fit_transform(X_fold_val[columns_to_normalize])
# 311/311 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - categorical_accuracy: 0.6039 - loss: 0.9903 - val_categorical_accuracy: 0.8406 - val_loss: 0.4496
# Epoch 2/100
# 311/311 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - categorical_accuracy: 0.8729 - loss: 0.3585 - val_categorical_accuracy: 0.8770 - val_loss: 0.3258
# Epoch 3/100
# 311/311 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - categorical_accuracy: 0.8901 - loss: 0.3062 - val_categorical_accuracy: 0.9061 - val_loss: 0.2703
# Epoch 4/100
# 311/311 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - categorical_accuracy: 0.8875 - loss: 0.3030 - val_categorical_accuracy: 0.8893 - val_loss: 0.2995
# Epoch 5/100
# 311/311 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - categorical_accuracy: 0.8997 - loss: 0.2718 - val_categorical_accuracy: 0.9065 - val_loss: 0.2590
# Epoch 6/100
# 311/311 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - categorical_accuracy: 0.9046 - loss: 0.2539 - val_categorical_accuracy: 0.9123 - val_loss: 0.2372
# Epoch 7/100
# 311/311 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - categorical_accuracy: 0.9026 - loss: 0.2510 - val_categorical_accuracy: 0.9111 - val_loss: 0.2267
# Epoch 8/100
# 311/311 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - categorical_accuracy: 0.9052 - loss: 0.2520 - val_categorical_accuracy: 0.8582 - val_loss: 0.4484
# Epoch 9/100
# 311/311 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - categorical_accuracy: 0.9087 - loss: 0.2407 - val_categorical_accuracy: 0.9100 - val_loss: 0.2307
# Epoch 10/100
# 311/311 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - categorical_accuracy: 0.9053 - loss: 0.2458 - val_categorical_accuracy: 0.9142 - val_loss: 0.2323
# Epoch 11/100
# 311/311 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - categorical_accuracy: 0.9097 - loss: 0.2434 - val_categorical_accuracy: 0.9180 - val_loss: 0.2295
# Epoch 12/100
# 311/311 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - categorical_accuracy: 0.9081 - loss: 0.2407 - val_categorical_accuracy: 0.9169 - val_loss: 0.2251
# Epoch 13/100
# 311/311 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - categorical_accuracy: 0.9093 - loss: 0.2402 - val_categorical_accuracy: 0.9092 - val_loss: 0.2437
# Epoch 14/100
# 311/311 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - categorical_accuracy: 0.9123 - loss: 0.2302 - val_categorical_accuracy: 0.9176 - val_loss: 0.2205
# Epoch 15/100
# 311/311 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - categorical_accuracy: 0.9140 - loss: 0.2289 - val_categorical_accuracy: 0.9111 - val_loss: 0.2364
# Epoch 16/100
# 311/311 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - categorical_accuracy: 0.9157 - loss: 0.2169 - val_categorical_accuracy: 0.9192 - val_loss: 0.2171
# Epoch 17/100
# 311/311 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - categorical_accuracy: 0.9138 - loss: 0.2246 - val_categorical_accuracy: 0.9107 - val_loss: 0.2349
# Epoch 18/100
# 311/311 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - categorical_accuracy: 0.9117 - loss: 0.2269 - val_categorical_accuracy: 0.9207 - val_loss: 0.2089
# Epoch 19/100
# 311/311 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - categorical_accuracy: 0.9111 - loss: 0.2327 - val_categorical_accuracy: 0.9130 - val_loss: 0.2328
# Epoch 20/100
# 311/311 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - categorical_accuracy: 0.9130 - loss: 0.2273 - val_categorical_accuracy: 0.9103 - val_loss: 0.2368
# Epoch 21/100
# 311/311 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - categorical_accuracy: 0.9110 - loss: 0.2346 - val_categorical_accuracy: 0.9184 - val_loss: 0.2109
# Epoch 22/100
# 311/311 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - categorical_accuracy: 0.9150 - loss: 0.2287 - val_categorical_accuracy: 0.9218 - val_loss: 0.2088
# Epoch 23/100
# 311/311 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - categorical_accuracy: 0.9160 - loss: 0.2208 - val_categorical_accuracy: 0.9188 - val_loss: 0.2187
# Epoch 24/100
# 311/311 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - categorical_accuracy: 0.9145 - loss: 0.2242 - val_categorical_accuracy: 0.9215 - val_loss: 0.2093
# Epoch 25/100
# 311/311 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - categorical_accuracy: 0.9179 - loss: 0.2105 - val_categorical_accuracy: 0.9172 - val_loss: 0.2168
# Epoch 26/100
# 311/311 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - categorical_accuracy: 0.9122 - loss: 0.2319 - val_categorical_accuracy: 0.9176 - val_loss: 0.2202
# Epoch 27/100
# 311/311 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - categorical_accuracy: 0.9146 - loss: 0.2257 - val_categorical_accuracy: 0.9188 - val_loss: 0.2155
# Epoch 28/100
# 311/311 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - categorical_accuracy: 0.9109 - loss: 0.2352 - val_categorical_accuracy: 0.9161 - val_loss: 0.2390
# Epoch 29/100
# 311/311 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - categorical_accuracy: 0.9152 - loss: 0.2169 - val_categorical_accuracy: 0.9199 - val_loss: 0.2096
# Epoch 30/100
# 311/311 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - categorical_accuracy: 0.9171 - loss: 0.2140 - val_categorical_accuracy: 0.9192 - val_loss: 0.2103
# Epoch 31/100
# 311/311 ━━━━━━━━━━━━━━━━━━━━ 0s 992us/step - categorical_accuracy: 0.9102 - loss: 0.2297 - val_categorical_accuracy: 0.9153 - val_loss: 0.2284
# Epoch 32/100
# 311/311 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - categorical_accuracy: 0.9162 - loss: 0.2242 - val_categorical_accuracy: 0.9199 - val_loss: 0.2094
# Epoch 33/100
# 311/311 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - categorical_accuracy: 0.9156 - loss: 0.2143 - val_categorical_accuracy: 0.9069 - val_loss: 0.2801
# Epoch 34/100
# 311/311 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - categorical_accuracy: 0.9106 - loss: 0.2176 - val_categorical_accuracy: 0.9165 - val_loss: 0.2249
# Epoch 35/100
# 311/311 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - categorical_accuracy: 0.9082 - loss: 0.2310 - val_categorical_accuracy: 0.9092 - val_loss: 0.2428
# Epoch 36/100
# 311/311 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - categorical_accuracy: 0.9157 - loss: 0.2206 - val_categorical_accuracy: 0.9199 - val_loss: 0.2116
# Epoch 37/100
# 311/311 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - categorical_accuracy: 0.9203 - loss: 0.2084 - val_categorical_accuracy: 0.9176 - val_loss: 0.2382
# Epoch 38/100
# 311/311 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - categorical_accuracy: 0.9174 - loss: 0.2165 - val_categorical_accuracy: 0.9130 - val_loss: 0.2267
# Epoch 39/100
# 311/311 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - categorical_accuracy: 0.9178 - loss: 0.2143 - val_categorical_accuracy: 0.9188 - val_loss: 0.2147
# Epoch 40/100
# 311/311 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - categorical_accuracy: 0.9122 - loss: 0.2256 - val_categorical_accuracy: 0.9184 - val_loss: 0.2134
# Epoch 41/100
# 311/311 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - categorical_accuracy: 0.9202 - loss: 0.2114 - val_categorical_accuracy: 0.9203 - val_loss: 0.2191
# Epoch 42/100
# 311/311 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - categorical_accuracy: 0.9136 - loss: 0.2227 - val_categorical_accuracy: 0.9195 - val_loss: 0.2084
# Epoch 43/100
# 311/311 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - categorical_accuracy: 0.9224 - loss: 0.2050 - val_categorical_accuracy: 0.9207 - val_loss: 0.2071
# Epoch 44/100
# 311/311 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - categorical_accuracy: 0.9156 - loss: 0.2115 - val_categorical_accuracy: 0.9195 - val_loss: 0.2106
# Epoch 45/100
# 311/311 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - categorical_accuracy: 0.9181 - loss: 0.2071 - val_categorical_accuracy: 0.9203 - val_loss: 0.2092
# Epoch 46/100
# 311/311 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - categorical_accuracy: 0.9150 - loss: 0.2154 - val_categorical_accuracy: 0.9153 - val_loss: 0.2353
# Epoch 47/100
# 311/311 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - categorical_accuracy: 0.9195 - loss: 0.2107 - val_categorical_accuracy: 0.9103 - val_loss: 0.2601
# Epoch 48/100
# 311/311 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - categorical_accuracy: 0.9134 - loss: 0.2174 - val_categorical_accuracy: 0.9096 - val_loss: 0.2544
# Epoch 49/100
# 311/311 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - categorical_accuracy: 0.9147 - loss: 0.2127 - val_categorical_accuracy: 0.9207 - val_loss: 0.2094
# Epoch 50/100
# 311/311 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - categorical_accuracy: 0.9152 - loss: 0.2197 - val_categorical_accuracy: 0.9211 - val_loss: 0.2035
# Epoch 51/100
# 311/311 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - categorical_accuracy: 0.9097 - loss: 0.2282 - val_categorical_accuracy: 0.9146 - val_loss: 0.2286
# Epoch 52/100
# 311/311 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - categorical_accuracy: 0.9166 - loss: 0.2157 - val_categorical_accuracy: 0.9195 - val_loss: 0.2089
# Epoch 53/100
# 311/311 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - categorical_accuracy: 0.9117 - loss: 0.2205 - val_categorical_accuracy: 0.9153 - val_loss: 0.2281
# Epoch 54/100
# 311/311 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - categorical_accuracy: 0.9145 - loss: 0.2288 - val_categorical_accuracy: 0.9195 - val_loss: 0.2156
# Epoch 55/100
# 311/311 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - categorical_accuracy: 0.9132 - loss: 0.2220 - val_categorical_accuracy: 0.9215 - val_loss: 0.2135
# Epoch 56/100
# 311/311 ━━━━━━━━━━━━━━━━━━━━ 0s 995us/step - categorical_accuracy: 0.9182 - loss: 0.2077 - val_categorical_accuracy: 0.9199 - val_loss: 0.2125
# Epoch 57/100
# 311/311 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - categorical_accuracy: 0.9200 - loss: 0.2041 - val_categorical_accuracy: 0.9169 - val_loss: 0.2106
# Epoch 58/100
# 311/311 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - categorical_accuracy: 0.9115 - loss: 0.2225 - val_categorical_accuracy: 0.9169 - val_loss: 0.2151
# Epoch 59/100
# 311/311 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - categorical_accuracy: 0.9141 - loss: 0.2173 - val_categorical_accuracy: 0.9199 - val_loss: 0.2129
# Epoch 60/100
# 311/311 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - categorical_accuracy: 0.9173 - loss: 0.2078 - val_categorical_accuracy: 0.9199 - val_loss: 0.2155
# Epoch 61/100
# 311/311 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - categorical_accuracy: 0.9162 - loss: 0.2198 - val_categorical_accuracy: 0.9199 - val_loss: 0.2141
# Epoch 62/100
# 311/311 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - categorical_accuracy: 0.9175 - loss: 0.2159 - val_categorical_accuracy: 0.9195 - val_loss: 0.2153
# Epoch 63/100
# 311/311 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - categorical_accuracy: 0.9139 - loss: 0.2150 - val_categorical_accuracy: 0.8874 - val_loss: 0.3692
# Epoch 64/100
# 311/311 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - categorical_accuracy: 0.9089 - loss: 0.2521 - val_categorical_accuracy: 0.9203 - val_loss: 0.2178
# Epoch 65/100
# 311/311 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - categorical_accuracy: 0.9161 - loss: 0.2125 - val_categorical_accuracy: 0.9199 - val_loss: 0.2119
# Epoch 66/100
# 311/311 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - categorical_accuracy: 0.9147 - loss: 0.2167 - val_categorical_accuracy: 0.9172 - val_loss: 0.2139
# Epoch 67/100
# 311/311 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - categorical_accuracy: 0.9156 - loss: 0.2144 - val_categorical_accuracy: 0.9211 - val_loss: 0.2089
# Epoch 68/100
# 311/311 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - categorical_accuracy: 0.9187 - loss: 0.2084 - val_categorical_accuracy: 0.8908 - val_loss: 0.3465
# Epoch 69/100
# 311/311 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - categorical_accuracy: 0.9060 - loss: 0.2396 - val_categorical_accuracy: 0.9180 - val_loss: 0.2142
# Epoch 70/100
# 311/311 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - categorical_accuracy: 0.9204 - loss: 0.2147 - val_categorical_accuracy: 0.9207 - val_loss: 0.2173
# Epoch 71/100
# 311/311 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - categorical_accuracy: 0.9178 - loss: 0.2124 - val_categorical_accuracy: 0.9207 - val_loss: 0.2117
# Epoch 72/100
# 311/311 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - categorical_accuracy: 0.9165 - loss: 0.2107 - val_categorical_accuracy: 0.9211 - val_loss: 0.2101
# Epoch 73/100
# 311/311 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - categorical_accuracy: 0.9170 - loss: 0.2119 - val_categorical_accuracy: 0.9199 - val_loss: 0.2117
# Epoch 74/100
# 311/311 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - categorical_accuracy: 0.9135 - loss: 0.2211 - val_categorical_accuracy: 0.9207 - val_loss: 0.2074
# Epoch 75/100
# 311/311 ━━━━━━━━━━━━━━━━━━━━ 0s 996us/step - categorical_accuracy: 0.9170 - loss: 0.2091 - val_categorical_accuracy: 0.9207 - val_loss: 0.2125
# Epoch 76/100
# 311/311 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - categorical_accuracy: 0.9194 - loss: 0.2009 - val_categorical_accuracy: 0.9176 - val_loss: 0.2162
# Epoch 77/100
# 311/311 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - categorical_accuracy: 0.9198 - loss: 0.2050 - val_categorical_accuracy: 0.9203 - val_loss: 0.2175
# Epoch 78/100
# 311/311 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - categorical_accuracy: 0.9179 - loss: 0.2077 - val_categorical_accuracy: 0.9188 - val_loss: 0.2134
# Epoch 79/100
# 311/311 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - categorical_accuracy: 0.9129 - loss: 0.2156 - val_categorical_accuracy: 0.9180 - val_loss: 0.2129
# Epoch 80/100
# 311/311 ━━━━━━━━━━━━━━━━━━━━ 0s 979us/step - categorical_accuracy: 0.9146 - loss: 0.2161 - val_categorical_accuracy: 0.9172 - val_loss: 0.2259
# Epoch 81/100
# 311/311 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - categorical_accuracy: 0.9212 - loss: 0.2107 - val_categorical_accuracy: 0.9180 - val_loss: 0.2243
# Epoch 82/100
# 311/311 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - categorical_accuracy: 0.9163 - loss: 0.2146 - val_categorical_accuracy: 0.9161 - val_loss: 0.2255
# Epoch 83/100
# 311/311 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - categorical_accuracy: 0.9186 - loss: 0.2030 - val_categorical_accuracy: 0.9123 - val_loss: 0.2317
# Epoch 84/100
# 311/311 ━━━━━━━━━━━━━━━━━━━━ 0s 971us/step - categorical_accuracy: 0.9180 - loss: 0.2083 - val_categorical_accuracy: 0.9176 - val_loss: 0.2151
# Epoch 85/100
# 311/311 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - categorical_accuracy: 0.9207 - loss: 0.2047 - val_categorical_accuracy: 0.9184 - val_loss: 0.2276
# Epoch 86/100
# 311/311 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - categorical_accuracy: 0.9150 - loss: 0.2144 - val_categorical_accuracy: 0.9199 - val_loss: 0.2127
# Epoch 87/100
# 311/311 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - categorical_accuracy: 0.9203 - loss: 0.1995 - val_categorical_accuracy: 0.9199 - val_loss: 0.2109
# Epoch 88/100
# 311/311 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - categorical_accuracy: 0.9131 - loss: 0.2183 - val_categorical_accuracy: 0.9180 - val_loss: 0.2224
# Epoch 89/100
# 311/311 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - categorical_accuracy: 0.9143 - loss: 0.2234 - val_categorical_accuracy: 0.9215 - val_loss: 0.2126
# Epoch 90/100
# 311/311 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - categorical_accuracy: 0.9179 - loss: 0.2104 - val_categorical_accuracy: 0.9180 - val_loss: 0.2279
# Epoch 91/100
# 311/311 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - categorical_accuracy: 0.9135 - loss: 0.2220 - val_categorical_accuracy: 0.9203 - val_loss: 0.2110
# Epoch 92/100
# 311/311 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - categorical_accuracy: 0.9158 - loss: 0.2106 - val_categorical_accuracy: 0.9199 - val_loss: 0.2134
# Epoch 93/100
# 311/311 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - categorical_accuracy: 0.9134 - loss: 0.2199 - val_categorical_accuracy: 0.9188 - val_loss: 0.2207
# Epoch 94/100
# 311/311 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - categorical_accuracy: 0.9193 - loss: 0.2065 - val_categorical_accuracy: 0.9207 - val_loss: 0.2035
# Epoch 95/100
# 311/311 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - categorical_accuracy: 0.9185 - loss: 0.2058 - val_categorical_accuracy: 0.9192 - val_loss: 0.2109
# Epoch 96/100
# 311/311 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - categorical_accuracy: 0.9131 - loss: 0.2138 - val_categorical_accuracy: 0.9192 - val_loss: 0.2372
# Epoch 97/100
# 311/311 ━━━━━━━━━━━━━━━━━━━━ 0s 996us/step - categorical_accuracy: 0.9089 - loss: 0.2380 - val_categorical_accuracy: 0.9211 - val_loss: 0.2100
# Epoch 98/100
# 311/311 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - categorical_accuracy: 0.9221 - loss: 0.2020 - val_categorical_accuracy: 0.9199 - val_loss: 0.2109
# Epoch 99/100
# 311/311 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - categorical_accuracy: 0.9124 - loss: 0.2175 - val_categorical_accuracy: 0.9172 - val_loss: 0.2284
# Epoch 100/100
# 311/311 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - categorical_accuracy: 0.9193 - loss: 0.2012 - val_categorical_accuracy: 0.9192 - val_loss: 0.2180
# 17588/17588 ━━━━━━━━━━━━━━━━━━━━ 5s 287us/step
# Fold 2:
#   Train: index=[     0      1      2 ... 506516 506517 506518]
#   Val:  index=[101304 101305 101306 ... 202605 202606 202607]
# /var/folders/qg/czgp8gyn3057jghb1vm_44yr0000gp/T/ipykernel_27255/140643231.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_fold_training[columns_to_normalize] = scaler.fit_transform(X_fold_training[columns_to_normalize])
# /var/folders/qg/czgp8gyn3057jghb1vm_44yr0000gp/T/ipykernel_27255/140643231.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_fold_val[columns_to_normalize] = scaler.fit_transform(X_fold_val[columns_to_normalize])
# Epoch 1/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - categorical_accuracy: 0.5522 - loss: 1.0562 - val_categorical_accuracy: 0.8688 - val_loss: 0.3602
# Epoch 2/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - categorical_accuracy: 0.8765 - loss: 0.3418 - val_categorical_accuracy: 0.8797 - val_loss: 0.2961
# Epoch 3/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - categorical_accuracy: 0.8782 - loss: 0.3215 - val_categorical_accuracy: 0.8882 - val_loss: 0.3010
# Epoch 4/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 962us/step - categorical_accuracy: 0.8940 - loss: 0.2881 - val_categorical_accuracy: 0.8403 - val_loss: 0.3529
# Epoch 5/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - categorical_accuracy: 0.9005 - loss: 0.2770 - val_categorical_accuracy: 0.8898 - val_loss: 0.2934
# Epoch 6/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - categorical_accuracy: 0.9044 - loss: 0.2496 - val_categorical_accuracy: 0.8988 - val_loss: 0.2600
# Epoch 7/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - categorical_accuracy: 0.9090 - loss: 0.2387 - val_categorical_accuracy: 0.8851 - val_loss: 0.2807
# Epoch 8/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - categorical_accuracy: 0.9074 - loss: 0.2488 - val_categorical_accuracy: 0.8801 - val_loss: 0.2964
# Epoch 9/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - categorical_accuracy: 0.9031 - loss: 0.2471 - val_categorical_accuracy: 0.8941 - val_loss: 0.2613
# Epoch 10/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - categorical_accuracy: 0.9112 - loss: 0.2322 - val_categorical_accuracy: 0.9019 - val_loss: 0.2546
# Epoch 11/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - categorical_accuracy: 0.9132 - loss: 0.2203 - val_categorical_accuracy: 0.8925 - val_loss: 0.2804
# Epoch 12/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 981us/step - categorical_accuracy: 0.9126 - loss: 0.2279 - val_categorical_accuracy: 0.8875 - val_loss: 0.2864
# Epoch 13/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 932us/step - categorical_accuracy: 0.9113 - loss: 0.2245 - val_categorical_accuracy: 0.8968 - val_loss: 0.2571
# Epoch 14/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 982us/step - categorical_accuracy: 0.9198 - loss: 0.2105 - val_categorical_accuracy: 0.9081 - val_loss: 0.2572
# Epoch 15/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - categorical_accuracy: 0.9114 - loss: 0.2207 - val_categorical_accuracy: 0.8910 - val_loss: 0.2782
# Epoch 16/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - categorical_accuracy: 0.9156 - loss: 0.2167 - val_categorical_accuracy: 0.8999 - val_loss: 0.2515
# Epoch 17/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - categorical_accuracy: 0.9120 - loss: 0.2335 - val_categorical_accuracy: 0.9011 - val_loss: 0.2585
# Epoch 18/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - categorical_accuracy: 0.9209 - loss: 0.2044 - val_categorical_accuracy: 0.8917 - val_loss: 0.2859
# Epoch 19/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 978us/step - categorical_accuracy: 0.9136 - loss: 0.2195 - val_categorical_accuracy: 0.8524 - val_loss: 0.3778
# Epoch 20/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - categorical_accuracy: 0.9125 - loss: 0.2277 - val_categorical_accuracy: 0.9065 - val_loss: 0.2549
# Epoch 21/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 971us/step - categorical_accuracy: 0.9121 - loss: 0.2339 - val_categorical_accuracy: 0.8758 - val_loss: 0.3817
# Epoch 22/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - categorical_accuracy: 0.9196 - loss: 0.2114 - val_categorical_accuracy: 0.9026 - val_loss: 0.2619
# Epoch 23/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - categorical_accuracy: 0.9229 - loss: 0.2007 - val_categorical_accuracy: 0.8902 - val_loss: 0.3213
# Epoch 24/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - categorical_accuracy: 0.9208 - loss: 0.2086 - val_categorical_accuracy: 0.9073 - val_loss: 0.2420
# Epoch 25/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - categorical_accuracy: 0.9188 - loss: 0.2095 - val_categorical_accuracy: 0.9058 - val_loss: 0.2472
# Epoch 26/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - categorical_accuracy: 0.9262 - loss: 0.1962 - val_categorical_accuracy: 0.9026 - val_loss: 0.2364
# Epoch 27/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - categorical_accuracy: 0.9088 - loss: 0.2333 - val_categorical_accuracy: 0.8984 - val_loss: 0.2812
# Epoch 28/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - categorical_accuracy: 0.9161 - loss: 0.2109 - val_categorical_accuracy: 0.9065 - val_loss: 0.2441
# Epoch 29/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 998us/step - categorical_accuracy: 0.9197 - loss: 0.2027 - val_categorical_accuracy: 0.9085 - val_loss: 0.2504
# Epoch 30/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - categorical_accuracy: 0.9222 - loss: 0.1995 - val_categorical_accuracy: 0.9065 - val_loss: 0.2583
# Epoch 31/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - categorical_accuracy: 0.9178 - loss: 0.2080 - val_categorical_accuracy: 0.8910 - val_loss: 0.2972
# Epoch 32/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - categorical_accuracy: 0.9208 - loss: 0.2061 - val_categorical_accuracy: 0.9046 - val_loss: 0.2450
# Epoch 33/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - categorical_accuracy: 0.9171 - loss: 0.2169 - val_categorical_accuracy: 0.9015 - val_loss: 0.2635
# Epoch 34/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - categorical_accuracy: 0.9183 - loss: 0.2131 - val_categorical_accuracy: 0.9085 - val_loss: 0.2436
# Epoch 35/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - categorical_accuracy: 0.9174 - loss: 0.2120 - val_categorical_accuracy: 0.9093 - val_loss: 0.2527
# Epoch 36/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - categorical_accuracy: 0.9153 - loss: 0.2193 - val_categorical_accuracy: 0.9073 - val_loss: 0.2434
# Epoch 37/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - categorical_accuracy: 0.9139 - loss: 0.2150 - val_categorical_accuracy: 0.9073 - val_loss: 0.2441
# Epoch 38/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - categorical_accuracy: 0.9205 - loss: 0.2077 - val_categorical_accuracy: 0.9042 - val_loss: 0.2543
# Epoch 39/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - categorical_accuracy: 0.9173 - loss: 0.2094 - val_categorical_accuracy: 0.9100 - val_loss: 0.2519
# Epoch 40/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - categorical_accuracy: 0.9189 - loss: 0.2168 - val_categorical_accuracy: 0.9069 - val_loss: 0.2674
# Epoch 41/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - categorical_accuracy: 0.9196 - loss: 0.2060 - val_categorical_accuracy: 0.9100 - val_loss: 0.2536
# Epoch 42/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - categorical_accuracy: 0.9202 - loss: 0.1994 - val_categorical_accuracy: 0.9097 - val_loss: 0.2530
# Epoch 43/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - categorical_accuracy: 0.9240 - loss: 0.1951 - val_categorical_accuracy: 0.9085 - val_loss: 0.2538
# Epoch 44/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - categorical_accuracy: 0.9238 - loss: 0.1975 - val_categorical_accuracy: 0.9093 - val_loss: 0.2510
# Epoch 45/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - categorical_accuracy: 0.9261 - loss: 0.1914 - val_categorical_accuracy: 0.9034 - val_loss: 0.2621
# Epoch 46/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 958us/step - categorical_accuracy: 0.9220 - loss: 0.2030 - val_categorical_accuracy: 0.8964 - val_loss: 0.3106
# Epoch 47/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 967us/step - categorical_accuracy: 0.9136 - loss: 0.2185 - val_categorical_accuracy: 0.9042 - val_loss: 0.2732
# Epoch 48/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 989us/step - categorical_accuracy: 0.9244 - loss: 0.1980 - val_categorical_accuracy: 0.9069 - val_loss: 0.2540
# Epoch 49/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 957us/step - categorical_accuracy: 0.9199 - loss: 0.2035 - val_categorical_accuracy: 0.9081 - val_loss: 0.2427
# Epoch 50/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 933us/step - categorical_accuracy: 0.9205 - loss: 0.2024 - val_categorical_accuracy: 0.8785 - val_loss: 0.3415
# Epoch 51/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 990us/step - categorical_accuracy: 0.9208 - loss: 0.2066 - val_categorical_accuracy: 0.9093 - val_loss: 0.2534
# Epoch 52/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 999us/step - categorical_accuracy: 0.9198 - loss: 0.2056 - val_categorical_accuracy: 0.9093 - val_loss: 0.2447
# Epoch 53/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - categorical_accuracy: 0.9195 - loss: 0.2087 - val_categorical_accuracy: 0.9093 - val_loss: 0.2556
# Epoch 54/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - categorical_accuracy: 0.9181 - loss: 0.2052 - val_categorical_accuracy: 0.9100 - val_loss: 0.2545
# Epoch 55/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - categorical_accuracy: 0.9240 - loss: 0.1955 - val_categorical_accuracy: 0.9097 - val_loss: 0.2540
# Epoch 56/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - categorical_accuracy: 0.9229 - loss: 0.1975 - val_categorical_accuracy: 0.9100 - val_loss: 0.2561
# Epoch 57/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - categorical_accuracy: 0.9216 - loss: 0.2023 - val_categorical_accuracy: 0.9093 - val_loss: 0.2612
# Epoch 58/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - categorical_accuracy: 0.9192 - loss: 0.2068 - val_categorical_accuracy: 0.8984 - val_loss: 0.2754
# Epoch 59/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - categorical_accuracy: 0.9182 - loss: 0.2026 - val_categorical_accuracy: 0.9019 - val_loss: 0.2685
# Epoch 60/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - categorical_accuracy: 0.9192 - loss: 0.2078 - val_categorical_accuracy: 0.9089 - val_loss: 0.2555
# Epoch 61/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - categorical_accuracy: 0.9207 - loss: 0.1945 - val_categorical_accuracy: 0.9073 - val_loss: 0.2754
# Epoch 62/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - categorical_accuracy: 0.9172 - loss: 0.2115 - val_categorical_accuracy: 0.9011 - val_loss: 0.2766
# Epoch 63/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - categorical_accuracy: 0.9197 - loss: 0.2032 - val_categorical_accuracy: 0.9081 - val_loss: 0.2590
# Epoch 64/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - categorical_accuracy: 0.9242 - loss: 0.1959 - val_categorical_accuracy: 0.9081 - val_loss: 0.2636
# Epoch 65/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - categorical_accuracy: 0.9284 - loss: 0.1861 - val_categorical_accuracy: 0.9062 - val_loss: 0.2646
# Epoch 66/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - categorical_accuracy: 0.9193 - loss: 0.2029 - val_categorical_accuracy: 0.8952 - val_loss: 0.3148
# Epoch 67/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 946us/step - categorical_accuracy: 0.9203 - loss: 0.2013 - val_categorical_accuracy: 0.8995 - val_loss: 0.3528
# Epoch 68/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - categorical_accuracy: 0.9203 - loss: 0.2144 - val_categorical_accuracy: 0.8548 - val_loss: 0.5439
# Epoch 69/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - categorical_accuracy: 0.9158 - loss: 0.2130 - val_categorical_accuracy: 0.9065 - val_loss: 0.2610
# Epoch 70/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - categorical_accuracy: 0.9204 - loss: 0.2002 - val_categorical_accuracy: 0.9058 - val_loss: 0.2604
# Epoch 71/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - categorical_accuracy: 0.9174 - loss: 0.2036 - val_categorical_accuracy: 0.9062 - val_loss: 0.2716
# Epoch 72/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - categorical_accuracy: 0.9248 - loss: 0.1939 - val_categorical_accuracy: 0.9081 - val_loss: 0.2494
# Epoch 73/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - categorical_accuracy: 0.9220 - loss: 0.1982 - val_categorical_accuracy: 0.9100 - val_loss: 0.2550
# Epoch 74/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - categorical_accuracy: 0.9214 - loss: 0.1986 - val_categorical_accuracy: 0.9097 - val_loss: 0.2580
# Epoch 75/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - categorical_accuracy: 0.9255 - loss: 0.1912 - val_categorical_accuracy: 0.9097 - val_loss: 0.2553
# Epoch 76/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - categorical_accuracy: 0.9251 - loss: 0.1931 - val_categorical_accuracy: 0.9108 - val_loss: 0.2588
# Epoch 77/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - categorical_accuracy: 0.9171 - loss: 0.2102 - val_categorical_accuracy: 0.8723 - val_loss: 0.4024
# Epoch 78/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 962us/step - categorical_accuracy: 0.9244 - loss: 0.1930 - val_categorical_accuracy: 0.9104 - val_loss: 0.2635
# Epoch 79/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - categorical_accuracy: 0.9243 - loss: 0.1922 - val_categorical_accuracy: 0.9077 - val_loss: 0.2796
# Epoch 80/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - categorical_accuracy: 0.9207 - loss: 0.1956 - val_categorical_accuracy: 0.9077 - val_loss: 0.2737
# Epoch 81/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 983us/step - categorical_accuracy: 0.9181 - loss: 0.2103 - val_categorical_accuracy: 0.9089 - val_loss: 0.2634
# Epoch 82/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - categorical_accuracy: 0.9257 - loss: 0.1886 - val_categorical_accuracy: 0.9093 - val_loss: 0.2686
# Epoch 83/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - categorical_accuracy: 0.9299 - loss: 0.1838 - val_categorical_accuracy: 0.9065 - val_loss: 0.2757
# Epoch 84/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 999us/step - categorical_accuracy: 0.9178 - loss: 0.2043 - val_categorical_accuracy: 0.9112 - val_loss: 0.2682
# Epoch 85/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - categorical_accuracy: 0.9241 - loss: 0.1961 - val_categorical_accuracy: 0.8777 - val_loss: 0.3852
# Epoch 86/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 994us/step - categorical_accuracy: 0.9174 - loss: 0.2087 - val_categorical_accuracy: 0.9116 - val_loss: 0.2883
# Epoch 87/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 967us/step - categorical_accuracy: 0.9257 - loss: 0.1910 - val_categorical_accuracy: 0.9093 - val_loss: 0.2843
# Epoch 88/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 990us/step - categorical_accuracy: 0.9225 - loss: 0.1920 - val_categorical_accuracy: 0.9073 - val_loss: 0.2971
# Epoch 89/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - categorical_accuracy: 0.9174 - loss: 0.2081 - val_categorical_accuracy: 0.9058 - val_loss: 0.3001
# Epoch 90/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - categorical_accuracy: 0.9196 - loss: 0.2109 - val_categorical_accuracy: 0.9097 - val_loss: 0.2719
# Epoch 91/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - categorical_accuracy: 0.9225 - loss: 0.1940 - val_categorical_accuracy: 0.9073 - val_loss: 0.2738
# Epoch 92/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - categorical_accuracy: 0.9250 - loss: 0.1912 - val_categorical_accuracy: 0.9034 - val_loss: 0.2784
# Epoch 93/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - categorical_accuracy: 0.9174 - loss: 0.2050 - val_categorical_accuracy: 0.9093 - val_loss: 0.2818
# Epoch 94/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - categorical_accuracy: 0.9251 - loss: 0.1933 - val_categorical_accuracy: 0.9104 - val_loss: 0.2696
# Epoch 95/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - categorical_accuracy: 0.9192 - loss: 0.2008 - val_categorical_accuracy: 0.9085 - val_loss: 0.2707
# Epoch 96/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - categorical_accuracy: 0.9213 - loss: 0.1948 - val_categorical_accuracy: 0.9054 - val_loss: 0.3072
# Epoch 97/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - categorical_accuracy: 0.9184 - loss: 0.2392 - val_categorical_accuracy: 0.8976 - val_loss: 0.2899
# Epoch 98/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - categorical_accuracy: 0.9195 - loss: 0.2008 - val_categorical_accuracy: 0.9011 - val_loss: 0.2845
# Epoch 99/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - categorical_accuracy: 0.9223 - loss: 0.1995 - val_categorical_accuracy: 0.9077 - val_loss: 0.2742
# Epoch 100/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - categorical_accuracy: 0.9239 - loss: 0.1902 - val_categorical_accuracy: 0.9093 - val_loss: 0.2765
# 17588/17588 ━━━━━━━━━━━━━━━━━━━━ 5s 298us/step
# Fold 3:
#   Train: index=[     0      1      2 ... 506516 506517 506518]
#   Val:  index=[202608 202609 202610 ... 303909 303910 303911]
# /var/folders/qg/czgp8gyn3057jghb1vm_44yr0000gp/T/ipykernel_27255/140643231.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_fold_training[columns_to_normalize] = scaler.fit_transform(X_fold_training[columns_to_normalize])
# Epoch 1/100
# /var/folders/qg/czgp8gyn3057jghb1vm_44yr0000gp/T/ipykernel_27255/140643231.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_fold_val[columns_to_normalize] = scaler.fit_transform(X_fold_val[columns_to_normalize])
# 311/311 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - categorical_accuracy: 0.5948 - loss: 1.0196 - val_categorical_accuracy: 0.8782 - val_loss: 0.3632
# Epoch 2/100
# 311/311 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - categorical_accuracy: 0.8782 - loss: 0.3431 - val_categorical_accuracy: 0.8169 - val_loss: 0.4975
# Epoch 3/100
# 311/311 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - categorical_accuracy: 0.8967 - loss: 0.2805 - val_categorical_accuracy: 0.8793 - val_loss: 0.3269
# Epoch 4/100
# 311/311 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - categorical_accuracy: 0.8960 - loss: 0.2762 - val_categorical_accuracy: 0.8801 - val_loss: 0.3085
# Epoch 5/100
# 311/311 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - categorical_accuracy: 0.8988 - loss: 0.2724 - val_categorical_accuracy: 0.8739 - val_loss: 0.3389
# Epoch 6/100
# 311/311 ━━━━━━━━━━━━━━━━━━━━ 0s 995us/step - categorical_accuracy: 0.9071 - loss: 0.2397 - val_categorical_accuracy: 0.8778 - val_loss: 0.3655
# Epoch 7/100
# 311/311 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - categorical_accuracy: 0.9044 - loss: 0.2571 - val_categorical_accuracy: 0.8257 - val_loss: 0.5082
# Epoch 8/100
# 311/311 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - categorical_accuracy: 0.9104 - loss: 0.2355 - val_categorical_accuracy: 0.8835 - val_loss: 0.3017
# Epoch 9/100
# 311/311 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - categorical_accuracy: 0.9131 - loss: 0.2285 - val_categorical_accuracy: 0.9088 - val_loss: 0.2423
# Epoch 10/100
# 311/311 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - categorical_accuracy: 0.9081 - loss: 0.2438 - val_categorical_accuracy: 0.8590 - val_loss: 0.3662
# Epoch 11/100
# 311/311 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - categorical_accuracy: 0.9127 - loss: 0.2218 - val_categorical_accuracy: 0.9057 - val_loss: 0.2461
# Epoch 12/100
# 311/311 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - categorical_accuracy: 0.9117 - loss: 0.2364 - val_categorical_accuracy: 0.8897 - val_loss: 0.3083
# Epoch 13/100
# 311/311 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - categorical_accuracy: 0.9124 - loss: 0.2263 - val_categorical_accuracy: 0.8992 - val_loss: 0.2804
# Epoch 14/100
# 311/311 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - categorical_accuracy: 0.9144 - loss: 0.2257 - val_categorical_accuracy: 0.8939 - val_loss: 0.2809
# Epoch 15/100
# 311/311 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - categorical_accuracy: 0.9152 - loss: 0.2161 - val_categorical_accuracy: 0.9027 - val_loss: 0.2518
# Epoch 16/100
# 311/311 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - categorical_accuracy: 0.9125 - loss: 0.2225 - val_categorical_accuracy: 0.9103 - val_loss: 0.2345
# Epoch 17/100
# 311/311 ━━━━━━━━━━━━━━━━━━━━ 0s 997us/step - categorical_accuracy: 0.9142 - loss: 0.2180 - val_categorical_accuracy: 0.8854 - val_loss: 0.3150
# Epoch 18/100
# 311/311 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - categorical_accuracy: 0.9111 - loss: 0.2275 - val_categorical_accuracy: 0.9092 - val_loss: 0.2792
# Epoch 19/100
# 311/311 ━━━━━━━━━━━━━━━━━━━━ 0s 975us/step - categorical_accuracy: 0.9117 - loss: 0.2336 - val_categorical_accuracy: 0.8950 - val_loss: 0.3159
# Epoch 20/100
# 311/311 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - categorical_accuracy: 0.9180 - loss: 0.2119 - val_categorical_accuracy: 0.9011 - val_loss: 0.2746
# Epoch 21/100
# 311/311 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - categorical_accuracy: 0.9184 - loss: 0.2196 - val_categorical_accuracy: 0.8743 - val_loss: 0.3744
# Epoch 22/100
# 311/311 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - categorical_accuracy: 0.9129 - loss: 0.2337 - val_categorical_accuracy: 0.9065 - val_loss: 0.2738
# Epoch 23/100
# 311/311 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - categorical_accuracy: 0.9152 - loss: 0.2142 - val_categorical_accuracy: 0.9011 - val_loss: 0.2742
# Epoch 24/100
# 311/311 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - categorical_accuracy: 0.9143 - loss: 0.2138 - val_categorical_accuracy: 0.8709 - val_loss: 0.3093
# Epoch 25/100
# 311/311 ━━━━━━━━━━━━━━━━━━━━ 0s 966us/step - categorical_accuracy: 0.9228 - loss: 0.2062 - val_categorical_accuracy: 0.9054 - val_loss: 0.2548
# Epoch 26/100
# 311/311 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - categorical_accuracy: 0.9178 - loss: 0.2088 - val_categorical_accuracy: 0.8992 - val_loss: 0.2685
# Epoch 27/100
# 311/311 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - categorical_accuracy: 0.9203 - loss: 0.2066 - val_categorical_accuracy: 0.9096 - val_loss: 0.2427
# Epoch 28/100
# 311/311 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - categorical_accuracy: 0.9144 - loss: 0.2230 - val_categorical_accuracy: 0.9015 - val_loss: 0.2622
# Epoch 29/100
# 311/311 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - categorical_accuracy: 0.9202 - loss: 0.2053 - val_categorical_accuracy: 0.9080 - val_loss: 0.2492
# Epoch 30/100
# 311/311 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - categorical_accuracy: 0.9184 - loss: 0.2116 - val_categorical_accuracy: 0.8870 - val_loss: 0.3526
# Epoch 31/100
# 311/311 ━━━━━━━━━━━━━━━━━━━━ 0s 959us/step - categorical_accuracy: 0.9165 - loss: 0.2189 - val_categorical_accuracy: 0.9015 - val_loss: 0.2811
# Epoch 32/100
# 311/311 ━━━━━━━━━━━━━━━━━━━━ 0s 957us/step - categorical_accuracy: 0.9191 - loss: 0.2058 - val_categorical_accuracy: 0.8981 - val_loss: 0.3296
# Epoch 33/100
# 311/311 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - categorical_accuracy: 0.9164 - loss: 0.2129 - val_categorical_accuracy: 0.9023 - val_loss: 0.2700
# Epoch 34/100
# 311/311 ━━━━━━━━━━━━━━━━━━━━ 0s 978us/step - categorical_accuracy: 0.9159 - loss: 0.2111 - val_categorical_accuracy: 0.8981 - val_loss: 0.2897
# Epoch 35/100
# 311/311 ━━━━━━━━━━━━━━━━━━━━ 0s 968us/step - categorical_accuracy: 0.9139 - loss: 0.2251 - val_categorical_accuracy: 0.9069 - val_loss: 0.2585
# Epoch 36/100
# 311/311 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - categorical_accuracy: 0.9150 - loss: 0.2091 - val_categorical_accuracy: 0.8973 - val_loss: 0.3172
# Epoch 37/100
# 311/311 ━━━━━━━━━━━━━━━━━━━━ 0s 987us/step - categorical_accuracy: 0.9169 - loss: 0.2164 - val_categorical_accuracy: 0.8330 - val_loss: 0.4150
# Epoch 38/100
# 311/311 ━━━━━━━━━━━━━━━━━━━━ 0s 959us/step - categorical_accuracy: 0.9158 - loss: 0.2156 - val_categorical_accuracy: 0.9100 - val_loss: 0.2542
# Epoch 39/100
# 311/311 ━━━━━━━━━━━━━━━━━━━━ 0s 939us/step - categorical_accuracy: 0.9203 - loss: 0.2060 - val_categorical_accuracy: 0.8188 - val_loss: 0.4799
# Epoch 40/100
# 311/311 ━━━━━━━━━━━━━━━━━━━━ 0s 907us/step - categorical_accuracy: 0.9122 - loss: 0.2288 - val_categorical_accuracy: 0.8962 - val_loss: 0.3060
# Epoch 41/100
# 311/311 ━━━━━━━━━━━━━━━━━━━━ 0s 954us/step - categorical_accuracy: 0.9215 - loss: 0.2040 - val_categorical_accuracy: 0.9073 - val_loss: 0.2596
# Epoch 42/100
# 311/311 ━━━━━━━━━━━━━━━━━━━━ 0s 939us/step - categorical_accuracy: 0.9174 - loss: 0.2126 - val_categorical_accuracy: 0.8475 - val_loss: 0.3944
# Epoch 43/100
# 311/311 ━━━━━━━━━━━━━━━━━━━━ 0s 898us/step - categorical_accuracy: 0.9188 - loss: 0.2063 - val_categorical_accuracy: 0.9080 - val_loss: 0.2506
# Epoch 44/100
# 311/311 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - categorical_accuracy: 0.9220 - loss: 0.1985 - val_categorical_accuracy: 0.9103 - val_loss: 0.2629
# Epoch 45/100
# 311/311 ━━━━━━━━━━━━━━━━━━━━ 0s 919us/step - categorical_accuracy: 0.9138 - loss: 0.2128 - val_categorical_accuracy: 0.9065 - val_loss: 0.2656
# Epoch 46/100
# 311/311 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - categorical_accuracy: 0.9174 - loss: 0.2054 - val_categorical_accuracy: 0.9057 - val_loss: 0.3411
# Epoch 47/100
# 311/311 ━━━━━━━━━━━━━━━━━━━━ 0s 947us/step - categorical_accuracy: 0.9113 - loss: 0.2149 - val_categorical_accuracy: 0.8989 - val_loss: 0.2552
# Epoch 48/100
# 311/311 ━━━━━━━━━━━━━━━━━━━━ 0s 949us/step - categorical_accuracy: 0.9215 - loss: 0.2006 - val_categorical_accuracy: 0.8958 - val_loss: 0.3233
# Epoch 49/100
# 311/311 ━━━━━━━━━━━━━━━━━━━━ 0s 953us/step - categorical_accuracy: 0.9117 - loss: 0.2212 - val_categorical_accuracy: 0.9057 - val_loss: 0.2715
# Epoch 50/100
# 311/311 ━━━━━━━━━━━━━━━━━━━━ 0s 890us/step - categorical_accuracy: 0.9192 - loss: 0.2088 - val_categorical_accuracy: 0.9119 - val_loss: 0.2477
# Epoch 51/100
# 311/311 ━━━━━━━━━━━━━━━━━━━━ 0s 875us/step - categorical_accuracy: 0.9234 - loss: 0.1957 - val_categorical_accuracy: 0.9088 - val_loss: 0.2525
# Epoch 52/100
# 311/311 ━━━━━━━━━━━━━━━━━━━━ 0s 960us/step - categorical_accuracy: 0.9217 - loss: 0.2075 - val_categorical_accuracy: 0.8992 - val_loss: 0.2607
# Epoch 53/100
# 311/311 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - categorical_accuracy: 0.9152 - loss: 0.2098 - val_categorical_accuracy: 0.8613 - val_loss: 0.3015
# Epoch 54/100
# 311/311 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - categorical_accuracy: 0.9189 - loss: 0.2055 - val_categorical_accuracy: 0.9057 - val_loss: 0.2828
# Epoch 55/100
# 311/311 ━━━━━━━━━━━━━━━━━━━━ 0s 942us/step - categorical_accuracy: 0.9159 - loss: 0.2102 - val_categorical_accuracy: 0.9042 - val_loss: 0.2704
# Epoch 56/100
# 311/311 ━━━━━━━━━━━━━━━━━━━━ 0s 915us/step - categorical_accuracy: 0.9175 - loss: 0.2114 - val_categorical_accuracy: 0.8935 - val_loss: 0.2722
# Epoch 57/100
# 311/311 ━━━━━━━━━━━━━━━━━━━━ 0s 918us/step - categorical_accuracy: 0.9173 - loss: 0.2087 - val_categorical_accuracy: 0.9115 - val_loss: 0.2291
# Epoch 58/100
# 311/311 ━━━━━━━━━━━━━━━━━━━━ 0s 996us/step - categorical_accuracy: 0.9189 - loss: 0.2051 - val_categorical_accuracy: 0.9008 - val_loss: 0.2795
# Epoch 59/100
# 311/311 ━━━━━━━━━━━━━━━━━━━━ 0s 922us/step - categorical_accuracy: 0.9224 - loss: 0.1958 - val_categorical_accuracy: 0.8912 - val_loss: 0.2990
# Epoch 60/100
# 311/311 ━━━━━━━━━━━━━━━━━━━━ 0s 917us/step - categorical_accuracy: 0.9182 - loss: 0.2061 - val_categorical_accuracy: 0.8663 - val_loss: 0.3926
# Epoch 61/100
# 311/311 ━━━━━━━━━━━━━━━━━━━━ 0s 895us/step - categorical_accuracy: 0.9251 - loss: 0.1921 - val_categorical_accuracy: 0.8977 - val_loss: 0.3249
# Epoch 62/100
# 311/311 ━━━━━━━━━━━━━━━━━━━━ 0s 901us/step - categorical_accuracy: 0.9154 - loss: 0.2058 - val_categorical_accuracy: 0.9008 - val_loss: 0.2551
# Epoch 63/100
# 311/311 ━━━━━━━━━━━━━━━━━━━━ 0s 919us/step - categorical_accuracy: 0.9155 - loss: 0.2131 - val_categorical_accuracy: 0.9031 - val_loss: 0.2580
# Epoch 64/100
# 311/311 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - categorical_accuracy: 0.9153 - loss: 0.2124 - val_categorical_accuracy: 0.9038 - val_loss: 0.2587
# Epoch 65/100
# 311/311 ━━━━━━━━━━━━━━━━━━━━ 0s 886us/step - categorical_accuracy: 0.9196 - loss: 0.2004 - val_categorical_accuracy: 0.9138 - val_loss: 0.2370
# Epoch 66/100
# 311/311 ━━━━━━━━━━━━━━━━━━━━ 0s 884us/step - categorical_accuracy: 0.9234 - loss: 0.1990 - val_categorical_accuracy: 0.8989 - val_loss: 0.2834
# Epoch 67/100
# 311/311 ━━━━━━━━━━━━━━━━━━━━ 0s 924us/step - categorical_accuracy: 0.9162 - loss: 0.2197 - val_categorical_accuracy: 0.9080 - val_loss: 0.2659
# Epoch 68/100
# 311/311 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - categorical_accuracy: 0.9182 - loss: 0.2036 - val_categorical_accuracy: 0.8774 - val_loss: 0.3087
# Epoch 69/100
# 311/311 ━━━━━━━━━━━━━━━━━━━━ 0s 959us/step - categorical_accuracy: 0.9196 - loss: 0.2020 - val_categorical_accuracy: 0.9000 - val_loss: 0.2953
# Epoch 70/100
# 311/311 ━━━━━━━━━━━━━━━━━━━━ 0s 890us/step - categorical_accuracy: 0.9198 - loss: 0.2025 - val_categorical_accuracy: 0.8958 - val_loss: 0.2541
# Epoch 71/100
# 311/311 ━━━━━━━━━━━━━━━━━━━━ 0s 885us/step - categorical_accuracy: 0.9226 - loss: 0.1999 - val_categorical_accuracy: 0.9027 - val_loss: 0.2821
# Epoch 72/100
# 311/311 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - categorical_accuracy: 0.9193 - loss: 0.2056 - val_categorical_accuracy: 0.9077 - val_loss: 0.2744
# Epoch 73/100
# 311/311 ━━━━━━━━━━━━━━━━━━━━ 0s 963us/step - categorical_accuracy: 0.9227 - loss: 0.2011 - val_categorical_accuracy: 0.9000 - val_loss: 0.2786
# Epoch 74/100
# 311/311 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - categorical_accuracy: 0.9177 - loss: 0.2084 - val_categorical_accuracy: 0.9057 - val_loss: 0.2454
# Epoch 75/100
# 311/311 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - categorical_accuracy: 0.9214 - loss: 0.2049 - val_categorical_accuracy: 0.8985 - val_loss: 0.3208
# Epoch 76/100
# 311/311 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - categorical_accuracy: 0.9182 - loss: 0.2025 - val_categorical_accuracy: 0.8640 - val_loss: 0.3932
# Epoch 77/100
# 311/311 ━━━━━━━━━━━━━━━━━━━━ 0s 963us/step - categorical_accuracy: 0.9188 - loss: 0.2016 - val_categorical_accuracy: 0.9008 - val_loss: 0.3189
# Epoch 78/100
# 311/311 ━━━━━━━━━━━━━━━━━━━━ 0s 929us/step - categorical_accuracy: 0.9172 - loss: 0.2110 - val_categorical_accuracy: 0.9119 - val_loss: 0.2463
# Epoch 79/100
# 311/311 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - categorical_accuracy: 0.9144 - loss: 0.2092 - val_categorical_accuracy: 0.9165 - val_loss: 0.2279
# Epoch 80/100
# 311/311 ━━━━━━━━━━━━━━━━━━━━ 0s 894us/step - categorical_accuracy: 0.9170 - loss: 0.2048 - val_categorical_accuracy: 0.9004 - val_loss: 0.2522
# Epoch 81/100
# 311/311 ━━━━━━━━━━━━━━━━━━━━ 0s 862us/step - categorical_accuracy: 0.9154 - loss: 0.2130 - val_categorical_accuracy: 0.9008 - val_loss: 0.2977
# Epoch 82/100
# 311/311 ━━━━━━━━━━━━━━━━━━━━ 0s 897us/step - categorical_accuracy: 0.9138 - loss: 0.2328 - val_categorical_accuracy: 0.9130 - val_loss: 0.2484
# Epoch 83/100
# 311/311 ━━━━━━━━━━━━━━━━━━━━ 0s 888us/step - categorical_accuracy: 0.9158 - loss: 0.2095 - val_categorical_accuracy: 0.9015 - val_loss: 0.3212
# Epoch 84/100
# 311/311 ━━━━━━━━━━━━━━━━━━━━ 0s 887us/step - categorical_accuracy: 0.9163 - loss: 0.2078 - val_categorical_accuracy: 0.9096 - val_loss: 0.2484
# Epoch 85/100
# 311/311 ━━━━━━━━━━━━━━━━━━━━ 0s 976us/step - categorical_accuracy: 0.9190 - loss: 0.1977 - val_categorical_accuracy: 0.9103 - val_loss: 0.2537
# Epoch 86/100
# 311/311 ━━━━━━━━━━━━━━━━━━━━ 0s 911us/step - categorical_accuracy: 0.9207 - loss: 0.1996 - val_categorical_accuracy: 0.9023 - val_loss: 0.2765
# Epoch 87/100
# 311/311 ━━━━━━━━━━━━━━━━━━━━ 0s 911us/step - categorical_accuracy: 0.9196 - loss: 0.2032 - val_categorical_accuracy: 0.9061 - val_loss: 0.2651
# Epoch 88/100
# 311/311 ━━━━━━━━━━━━━━━━━━━━ 0s 959us/step - categorical_accuracy: 0.9189 - loss: 0.2009 - val_categorical_accuracy: 0.9008 - val_loss: 0.2984
# Epoch 89/100
# 311/311 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - categorical_accuracy: 0.9183 - loss: 0.2054 - val_categorical_accuracy: 0.8889 - val_loss: 0.3516
# Epoch 90/100
# ...
# /var/folders/qg/czgp8gyn3057jghb1vm_44yr0000gp/T/ipykernel_27255/140643231.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_fold_val[columns_to_normalize] = scaler.fit_transform(X_fold_val[columns_to_normalize])
# Epoch 1/100
# 315/315 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - categorical_accuracy: 0.5404 - loss: 1.0750 - val_categorical_accuracy: 0.7293 - val_loss: 0.9523
# Epoch 2/100
# 315/315 ━━━━━━━━━━━━━━━━━━━━ 0s 934us/step - categorical_accuracy: 0.8817 - loss: 0.3446 - val_categorical_accuracy: 0.8317 - val_loss: 0.4531
# Epoch 3/100
# 315/315 ━━━━━━━━━━━━━━━━━━━━ 0s 930us/step - categorical_accuracy: 0.8915 - loss: 0.2851 - val_categorical_accuracy: 0.8060 - val_loss: 0.6099
# Epoch 4/100
# 315/315 ━━━━━━━━━━━━━━━━━━━━ 0s 901us/step - categorical_accuracy: 0.8910 - loss: 0.3033 - val_categorical_accuracy: 0.7908 - val_loss: 0.6500
# Epoch 5/100
# 315/315 ━━━━━━━━━━━━━━━━━━━━ 0s 906us/step - categorical_accuracy: 0.8938 - loss: 0.2636 - val_categorical_accuracy: 0.7972 - val_loss: 0.7138
# Epoch 6/100
# 315/315 ━━━━━━━━━━━━━━━━━━━━ 0s 948us/step - categorical_accuracy: 0.9046 - loss: 0.2475 - val_categorical_accuracy: 0.7827 - val_loss: 0.8100
# Epoch 7/100
# 315/315 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - categorical_accuracy: 0.9032 - loss: 0.2466 - val_categorical_accuracy: 0.8325 - val_loss: 0.4636
# Epoch 8/100
# 315/315 ━━━━━━━━━━━━━━━━━━━━ 0s 980us/step - categorical_accuracy: 0.9092 - loss: 0.2414 - val_categorical_accuracy: 0.8719 - val_loss: 0.3739
# Epoch 9/100
# 315/315 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - categorical_accuracy: 0.9084 - loss: 0.2394 - val_categorical_accuracy: 0.8811 - val_loss: 0.3114
# Epoch 10/100
# 315/315 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - categorical_accuracy: 0.9024 - loss: 0.2573 - val_categorical_accuracy: 0.8514 - val_loss: 0.4270
# Epoch 11/100
# 315/315 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - categorical_accuracy: 0.9103 - loss: 0.2336 - val_categorical_accuracy: 0.8590 - val_loss: 0.4092
# Epoch 12/100
# 315/315 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - categorical_accuracy: 0.9111 - loss: 0.2333 - val_categorical_accuracy: 0.7948 - val_loss: 0.5872
# Epoch 13/100
# 315/315 ━━━━━━━━━━━━━━━━━━━━ 0s 996us/step - categorical_accuracy: 0.9046 - loss: 0.2401 - val_categorical_accuracy: 0.8807 - val_loss: 0.3521
# Epoch 14/100
# 315/315 ━━━━━━━━━━━━━━━━━━━━ 0s 947us/step - categorical_accuracy: 0.9059 - loss: 0.2349 - val_categorical_accuracy: 0.8980 - val_loss: 0.3136
# Epoch 15/100
# 315/315 ━━━━━━━━━━━━━━━━━━━━ 0s 961us/step - categorical_accuracy: 0.9128 - loss: 0.2335 - val_categorical_accuracy: 0.9052 - val_loss: 0.2554
# Epoch 16/100
# 315/315 ━━━━━━━━━━━━━━━━━━━━ 0s 976us/step - categorical_accuracy: 0.9087 - loss: 0.2253 - val_categorical_accuracy: 0.8153 - val_loss: 0.5492
# Epoch 17/100
# 315/315 ━━━━━━━━━━━━━━━━━━━━ 0s 897us/step - categorical_accuracy: 0.9093 - loss: 0.2340 - val_categorical_accuracy: 0.8964 - val_loss: 0.2892
# Epoch 18/100
# 315/315 ━━━━━━━━━━━━━━━━━━━━ 0s 969us/step - categorical_accuracy: 0.9125 - loss: 0.2292 - val_categorical_accuracy: 0.9080 - val_loss: 0.2526
# Epoch 19/100
# 315/315 ━━━━━━━━━━━━━━━━━━━━ 0s 925us/step - categorical_accuracy: 0.9144 - loss: 0.2192 - val_categorical_accuracy: 0.8831 - val_loss: 0.3148
# Epoch 20/100
# 315/315 ━━━━━━━━━━━━━━━━━━━━ 0s 909us/step - categorical_accuracy: 0.9048 - loss: 0.2433 - val_categorical_accuracy: 0.8968 - val_loss: 0.3051
# Epoch 21/100
# 315/315 ━━━━━━━━━━━━━━━━━━━━ 0s 935us/step - categorical_accuracy: 0.9139 - loss: 0.2176 - val_categorical_accuracy: 0.9032 - val_loss: 0.2673
# Epoch 22/100
# 315/315 ━━━━━━━━━━━━━━━━━━━━ 0s 914us/step - categorical_accuracy: 0.9126 - loss: 0.2210 - val_categorical_accuracy: 0.8855 - val_loss: 0.3280
# Epoch 23/100
# 315/315 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - categorical_accuracy: 0.9057 - loss: 0.2369 - val_categorical_accuracy: 0.9149 - val_loss: 0.2410
# Epoch 24/100
# 315/315 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - categorical_accuracy: 0.9183 - loss: 0.2078 - val_categorical_accuracy: 0.8847 - val_loss: 0.3682
# Epoch 25/100
# 315/315 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - categorical_accuracy: 0.9124 - loss: 0.2202 - val_categorical_accuracy: 0.9092 - val_loss: 0.2529
# Epoch 26/100
# 315/315 ━━━━━━━━━━━━━━━━━━━━ 0s 979us/step - categorical_accuracy: 0.9169 - loss: 0.2113 - val_categorical_accuracy: 0.8787 - val_loss: 0.3661
# Epoch 27/100
# 315/315 ━━━━━━━━━━━━━━━━━━━━ 0s 970us/step - categorical_accuracy: 0.9076 - loss: 0.2326 - val_categorical_accuracy: 0.8932 - val_loss: 0.3011
# Epoch 28/100
# 315/315 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - categorical_accuracy: 0.9184 - loss: 0.2120 - val_categorical_accuracy: 0.9100 - val_loss: 0.2472
# Epoch 29/100
# 315/315 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - categorical_accuracy: 0.9148 - loss: 0.2332 - val_categorical_accuracy: 0.8888 - val_loss: 0.3085
# Epoch 30/100
# 315/315 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - categorical_accuracy: 0.9188 - loss: 0.2074 - val_categorical_accuracy: 0.8542 - val_loss: 0.4155
# Epoch 31/100
# 315/315 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - categorical_accuracy: 0.9082 - loss: 0.2469 - val_categorical_accuracy: 0.8863 - val_loss: 0.3040
# Epoch 32/100
# 315/315 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - categorical_accuracy: 0.9164 - loss: 0.2142 - val_categorical_accuracy: 0.8542 - val_loss: 0.4059
# Epoch 33/100
# 315/315 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - categorical_accuracy: 0.9124 - loss: 0.2188 - val_categorical_accuracy: 0.9032 - val_loss: 0.2840
# Epoch 34/100
# 315/315 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - categorical_accuracy: 0.9160 - loss: 0.2172 - val_categorical_accuracy: 0.8984 - val_loss: 0.2715
# Epoch 35/100
# 315/315 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - categorical_accuracy: 0.9140 - loss: 0.2190 - val_categorical_accuracy: 0.9044 - val_loss: 0.2916
# Epoch 36/100
# 315/315 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - categorical_accuracy: 0.9154 - loss: 0.2159 - val_categorical_accuracy: 0.8900 - val_loss: 0.4080
# Epoch 37/100
# 315/315 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - categorical_accuracy: 0.9194 - loss: 0.2125 - val_categorical_accuracy: 0.9032 - val_loss: 0.2646
# Epoch 38/100
# 315/315 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - categorical_accuracy: 0.9163 - loss: 0.2168 - val_categorical_accuracy: 0.9028 - val_loss: 0.2931
# Epoch 39/100
# 315/315 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - categorical_accuracy: 0.9154 - loss: 0.2165 - val_categorical_accuracy: 0.8896 - val_loss: 0.3306
# Epoch 40/100
# 315/315 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - categorical_accuracy: 0.9184 - loss: 0.2092 - val_categorical_accuracy: 0.8956 - val_loss: 0.2753
# Epoch 41/100
# 315/315 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - categorical_accuracy: 0.9107 - loss: 0.2216 - val_categorical_accuracy: 0.9088 - val_loss: 0.2356
# Epoch 42/100
# 315/315 ━━━━━━━━━━━━━━━━━━━━ 0s 981us/step - categorical_accuracy: 0.9137 - loss: 0.2194 - val_categorical_accuracy: 0.9012 - val_loss: 0.3185
# Epoch 43/100
# 315/315 ━━━━━━━━━━━━━━━━━━━━ 0s 971us/step - categorical_accuracy: 0.9123 - loss: 0.2212 - val_categorical_accuracy: 0.9016 - val_loss: 0.2728
# Epoch 44/100
# 315/315 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - categorical_accuracy: 0.9142 - loss: 0.2097 - val_categorical_accuracy: 0.9108 - val_loss: 0.2441
# Epoch 45/100
# 315/315 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - categorical_accuracy: 0.9139 - loss: 0.2202 - val_categorical_accuracy: 0.9048 - val_loss: 0.2723
# Epoch 46/100
# 315/315 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - categorical_accuracy: 0.9200 - loss: 0.2062 - val_categorical_accuracy: 0.8847 - val_loss: 0.3162
# Epoch 47/100
# 315/315 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - categorical_accuracy: 0.9168 - loss: 0.2168 - val_categorical_accuracy: 0.9100 - val_loss: 0.2395
# Epoch 48/100
# 315/315 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - categorical_accuracy: 0.9185 - loss: 0.2106 - val_categorical_accuracy: 0.9060 - val_loss: 0.2755
# Epoch 49/100
# 315/315 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - categorical_accuracy: 0.9092 - loss: 0.2186 - val_categorical_accuracy: 0.9060 - val_loss: 0.2732
# Epoch 50/100
# 315/315 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - categorical_accuracy: 0.9189 - loss: 0.2059 - val_categorical_accuracy: 0.9084 - val_loss: 0.2459
# Epoch 51/100
# 315/315 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - categorical_accuracy: 0.9182 - loss: 0.2096 - val_categorical_accuracy: 0.9064 - val_loss: 0.2887
# Epoch 52/100
# 315/315 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - categorical_accuracy: 0.9160 - loss: 0.2156 - val_categorical_accuracy: 0.8831 - val_loss: 0.3517
# Epoch 53/100
# 315/315 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - categorical_accuracy: 0.9155 - loss: 0.2144 - val_categorical_accuracy: 0.9008 - val_loss: 0.2958
# Epoch 54/100
# 315/315 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - categorical_accuracy: 0.9113 - loss: 0.2239 - val_categorical_accuracy: 0.8711 - val_loss: 0.3985
# Epoch 55/100
# 315/315 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - categorical_accuracy: 0.9187 - loss: 0.2045 - val_categorical_accuracy: 0.9044 - val_loss: 0.2696
# Epoch 56/100
# 315/315 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - categorical_accuracy: 0.9175 - loss: 0.2119 - val_categorical_accuracy: 0.8843 - val_loss: 0.3933
# Epoch 57/100
# 315/315 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - categorical_accuracy: 0.9133 - loss: 0.2178 - val_categorical_accuracy: 0.9080 - val_loss: 0.2639
# Epoch 58/100
# 315/315 ━━━━━━━━━━━━━━━━━━━━ 0s 947us/step - categorical_accuracy: 0.9161 - loss: 0.2136 - val_categorical_accuracy: 0.9100 - val_loss: 0.2574
# Epoch 59/100
# 315/315 ━━━━━━━━━━━━━━━━━━━━ 0s 960us/step - categorical_accuracy: 0.9208 - loss: 0.2022 - val_categorical_accuracy: 0.8996 - val_loss: 0.2839
# Epoch 60/100
# 315/315 ━━━━━━━━━━━━━━━━━━━━ 0s 972us/step - categorical_accuracy: 0.9191 - loss: 0.2021 - val_categorical_accuracy: 0.9020 - val_loss: 0.3049
# Epoch 61/100
# 315/315 ━━━━━━━━━━━━━━━━━━━━ 0s 965us/step - categorical_accuracy: 0.9177 - loss: 0.2155 - val_categorical_accuracy: 0.9008 - val_loss: 0.2827
# Epoch 62/100
# 315/315 ━━━━━━━━━━━━━━━━━━━━ 0s 989us/step - categorical_accuracy: 0.9193 - loss: 0.2052 - val_categorical_accuracy: 0.9064 - val_loss: 0.2624
# Epoch 63/100
# 315/315 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - categorical_accuracy: 0.9226 - loss: 0.2023 - val_categorical_accuracy: 0.9088 - val_loss: 0.2602
# Epoch 64/100
# 315/315 ━━━━━━━━━━━━━━━━━━━━ 0s 916us/step - categorical_accuracy: 0.9190 - loss: 0.2012 - val_categorical_accuracy: 0.9092 - val_loss: 0.2539
# Epoch 65/100
# 315/315 ━━━━━━━━━━━━━━━━━━━━ 0s 997us/step - categorical_accuracy: 0.9150 - loss: 0.2076 - val_categorical_accuracy: 0.8940 - val_loss: 0.2896
# Epoch 66/100
# 315/315 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - categorical_accuracy: 0.9202 - loss: 0.2026 - val_categorical_accuracy: 0.9004 - val_loss: 0.2898
# Epoch 67/100
# 315/315 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - categorical_accuracy: 0.9146 - loss: 0.2098 - val_categorical_accuracy: 0.8984 - val_loss: 0.2861
# Epoch 68/100
# 315/315 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - categorical_accuracy: 0.9139 - loss: 0.2169 - val_categorical_accuracy: 0.9036 - val_loss: 0.2609
# Epoch 69/100
# 315/315 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - categorical_accuracy: 0.9176 - loss: 0.2147 - val_categorical_accuracy: 0.8827 - val_loss: 0.3827
# Epoch 70/100
# 315/315 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - categorical_accuracy: 0.9150 - loss: 0.2124 - val_categorical_accuracy: 0.8851 - val_loss: 0.4180
# Epoch 71/100
# 315/315 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - categorical_accuracy: 0.9174 - loss: 0.2083 - val_categorical_accuracy: 0.9092 - val_loss: 0.2500
# Epoch 72/100
# 315/315 ━━━━━━━━━━━━━━━━━━━━ 0s 965us/step - categorical_accuracy: 0.9161 - loss: 0.2054 - val_categorical_accuracy: 0.8566 - val_loss: 0.5556
# Epoch 73/100
# 315/315 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - categorical_accuracy: 0.9165 - loss: 0.2116 - val_categorical_accuracy: 0.8944 - val_loss: 0.3320
# Epoch 74/100
# 315/315 ━━━━━━━━━━━━━━━━━━━━ 0s 994us/step - categorical_accuracy: 0.9151 - loss: 0.2158 - val_categorical_accuracy: 0.8876 - val_loss: 0.3788
# Epoch 75/100
# 315/315 ━━━━━━━━━━━━━━━━━━━━ 0s 967us/step - categorical_accuracy: 0.9122 - loss: 0.2196 - val_categorical_accuracy: 0.8908 - val_loss: 0.2863
# Epoch 76/100
# 315/315 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - categorical_accuracy: 0.9189 - loss: 0.2084 - val_categorical_accuracy: 0.8976 - val_loss: 0.3172
# Epoch 77/100
# 315/315 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - categorical_accuracy: 0.9174 - loss: 0.2066 - val_categorical_accuracy: 0.9072 - val_loss: 0.2571
# Epoch 78/100
# 315/315 ━━━━━━━━━━━━━━━━━━━━ 0s 936us/step - categorical_accuracy: 0.9157 - loss: 0.2147 - val_categorical_accuracy: 0.9028 - val_loss: 0.2736
# Epoch 79/100
# 315/315 ━━━━━━━━━━━━━━━━━━━━ 0s 950us/step - categorical_accuracy: 0.9199 - loss: 0.2061 - val_categorical_accuracy: 0.9044 - val_loss: 0.2654
# Epoch 80/100
# 315/315 ━━━━━━━━━━━━━━━━━━━━ 0s 978us/step - categorical_accuracy: 0.9150 - loss: 0.2093 - val_categorical_accuracy: 0.8851 - val_loss: 0.3375
# Epoch 81/100
# 315/315 ━━━━━━━━━━━━━━━━━━━━ 0s 965us/step - categorical_accuracy: 0.9179 - loss: 0.2109 - val_categorical_accuracy: 0.8867 - val_loss: 0.3447
# Epoch 82/100
# 315/315 ━━━━━━━━━━━━━━━━━━━━ 0s 934us/step - categorical_accuracy: 0.9133 - loss: 0.2171 - val_categorical_accuracy: 0.8976 - val_loss: 0.2807
# Epoch 83/100
# 315/315 ━━━━━━━━━━━━━━━━━━━━ 0s 926us/step - categorical_accuracy: 0.9169 - loss: 0.2035 - val_categorical_accuracy: 0.9048 - val_loss: 0.2558
# Epoch 84/100
# 315/315 ━━━━━━━━━━━━━━━━━━━━ 0s 914us/step - categorical_accuracy: 0.9194 - loss: 0.2014 - val_categorical_accuracy: 0.9076 - val_loss: 0.2707
# Epoch 85/100
# 315/315 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - categorical_accuracy: 0.9217 - loss: 0.2013 - val_categorical_accuracy: 0.9092 - val_loss: 0.2905
# Epoch 86/100
# 315/315 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - categorical_accuracy: 0.9152 - loss: 0.2090 - val_categorical_accuracy: 0.8984 - val_loss: 0.3460
# Epoch 87/100
# 315/315 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - categorical_accuracy: 0.9136 - loss: 0.2166 - val_categorical_accuracy: 0.9108 - val_loss: 0.2654
# Epoch 88/100
# 315/315 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - categorical_accuracy: 0.9162 - loss: 0.2124 - val_categorical_accuracy: 0.8884 - val_loss: 0.3465
# Epoch 89/100
# 315/315 ━━━━━━━━━━━━━━━━━━━━ 0s 991us/step - categorical_accuracy: 0.9168 - loss: 0.2074 - val_categorical_accuracy: 0.9116 - val_loss: 0.2403
# Epoch 90/100
# 315/315 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - categorical_accuracy: 0.9214 - loss: 0.1988 - val_categorical_accuracy: 0.9080 - val_loss: 0.2458
# Epoch 91/100
# 315/315 ━━━━━━━━━━━━━━━━━━━━ 0s 963us/step - categorical_accuracy: 0.9195 - loss: 0.2107 - val_categorical_accuracy: 0.9104 - val_loss: 0.2403
# Epoch 92/100
# 315/315 ━━━━━━━━━━━━━━━━━━━━ 0s 984us/step - categorical_accuracy: 0.9200 - loss: 0.2040 - val_categorical_accuracy: 0.9044 - val_loss: 0.2843
# Epoch 93/100
# 315/315 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - categorical_accuracy: 0.9182 - loss: 0.2050 - val_categorical_accuracy: 0.8960 - val_loss: 0.3372
# Epoch 94/100
# 315/315 ━━━━━━━━━━━━━━━━━━━━ 0s 992us/step - categorical_accuracy: 0.9187 - loss: 0.2021 - val_categorical_accuracy: 0.8892 - val_loss: 0.2935
# Epoch 95/100
# 315/315 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - categorical_accuracy: 0.9149 - loss: 0.2164 - val_categorical_accuracy: 0.9024 - val_loss: 0.3153
# Epoch 96/100
# 315/315 ━━━━━━━━━━━━━━━━━━━━ 0s 962us/step - categorical_accuracy: 0.9147 - loss: 0.2170 - val_categorical_accuracy: 0.9120 - val_loss: 0.2563
# Epoch 97/100
# 315/315 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - categorical_accuracy: 0.9142 - loss: 0.2151 - val_categorical_accuracy: 0.9084 - val_loss: 0.2665
# Epoch 98/100
# 315/315 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - categorical_accuracy: 0.9151 - loss: 0.2063 - val_categorical_accuracy: 0.8972 - val_loss: 0.3392
# Epoch 99/100
# 315/315 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - categorical_accuracy: 0.9188 - loss: 0.2047 - val_categorical_accuracy: 0.9133 - val_loss: 0.2599
# Epoch 100/100
# 315/315 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - categorical_accuracy: 0.9176 - loss: 0.2055 - val_categorical_accuracy: 0.9012 - val_loss: 0.3048
# 17588/17588 ━━━━━━━━━━━━━━━━━━━━ 5s 290us/step

# %%
metric_names = list(histories[0].history.keys())
avg_metrics = {metric: [] for metric in metric_names}

# Compute mean per epoch across folds
for metric in metric_names:
    avg_metrics[metric] = np.mean([fold.history[metric] for fold in histories], axis=0)

# Print average metrics
for metric, values in avg_metrics.items():
    print(f"Average {metric}: {values[-1]:.4f}")  # Showing the last epoch's value
# Out:
# Average categorical_accuracy: 0.9185
# Average loss: 0.2047
# Average val_categorical_accuracy: 0.9092
# Average val_loss: 0.2729

# %%
threshold = 0.5
avg_predictions = np.mean(predictions, axis=0)  # Mean ensemble
y_pred_binary = (avg_predictions >= threshold).astype(int)

# %%
print(classification_report(y_test_binary, y_pred_binary, zero_division=0, digits=4))
# Out:
#               precision    recall  f1-score   support
#
#            0     0.9996    0.8420    0.9141    365427
#            1     0.9990    0.9993    0.9991     47234
#            2     0.4665    0.9599    0.6279      3863
#            3     0.7418    0.9966    0.8505    141203
#            4     0.6669    0.7996    0.7272      2739
#            5     0.8769    0.8115    0.8429      2334
#
#    micro avg     0.9019    0.8945    0.8982    562800
#    macro avg     0.7918    0.9015    0.8270    562800
# weighted avg     0.9291    0.8945    0.9021    562800
#  samples avg     0.8945    0.8945    0.8945    562800

# %%
# Plot loss and accuraccy of training

# Plot accuracy
plt.plot(avg_metrics['categorical_accuracy'], label='Training Accuracy')
plt.plot(avg_metrics['val_categorical_accuracy'], label='Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.title('Training and Validation Accuracy')
plt.show()

# Plot loss
plt.plot(avg_metrics['loss'], label='Training Loss')
plt.plot(avg_metrics['val_loss'], label='Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.title('Training and Validation Loss')
plt.show()

# %%
# Compute multilabel confusion matrix
mcm = multilabel_confusion_matrix(y_test_binary, y_pred_binary)

attack_labels = ["Benign", "DDoS_LOIT", "DoS_GoldenEye", "DoS_Hulk", "DoS_Slowhttptest", "DoS_Slowloris"]

# Set up the plot
fig, axes = plt.subplots(2, 3, figsize=(12, 8))

# Plot each confusion matrix as a heatmap
for i, ax in enumerate(axes.flat):
    cm = mcm[i]
    
    # Calculate percentages
    cm_percent = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis] * 100  # Normalize by row (True Labels)
    
    # Annotate with both raw count and percentage
    annotations = []
    for j in range(cm.shape[0]):  # Loop through each row
        row_annotations = []
        for k in range(cm.shape[1]):  # Loop through each column
            count = cm[j, k]
            percentage = cm_percent[j, k]
            row_annotations.append(f'{count}\n({percentage:.2f}%)')
        annotations.append(row_annotations)
    
    # Plot the confusion matrix with both numbers and percentages
    sns.heatmap(cm_percent, annot=annotations, fmt='', cmap='Blues', cbar=False, ax=ax, 
                annot_kws={"size": 10}, xticklabels=['Negative', 'Positive'], yticklabels=['Negative', 'Positive'])
    
    ax.set_title(f'Confusion Matrix {attack_labels[i]}')
    ax.set_xlabel('Predicted Labels')
    ax.set_ylabel('True Labels')

plt.tight_layout()
plt.show()

# %%
# Number of classes
n_classes = y_test_binary.shape[1]
labels = ["Benign", "DDoS_LOIT", "DoS_GoldenEye", "DoS_Hulk", "DoS_Slowhttptest", "DoS_Slowloris"]

# Plot ROC curve for each class
plt.figure(figsize=(8, 6))
for i in range(n_classes):
    fpr, tpr, _ = roc_curve(y_test_binary[:, i], y_pred_binary[:, i])
    roc_auc = auc(fpr, tpr)  # Compute AUC
    plt.plot(fpr, tpr, label=f'{labels[i]} (AUC = {roc_auc:.2f})')

# Plot random classifier (diagonal line)
# plt.plot([0, 1], [0, 1], 'k--', label='Random (AUC = 0.50)')

# Formatting
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curves for All Classes')
plt.legend()
plt.grid()
plt.show()

# %%
# Compute micro-average ROC curve and AUC
fpr, tpr, _ = roc_curve(y_test_binary.ravel(), y_pred_binary.ravel())
roc_auc = auc(fpr, tpr)

# Plot the ROC curve
plt.figure(figsize=(8, 6))
plt.plot(fpr, tpr, label=f'AUC = {roc_auc:.2f}')
# Plot random classifier
# plt.plot([0, 1], [0, 1], 'k--', label='Random (AUC = 0.50)')

# Formatting
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('MLP Batch learning ROC AUC Score')
plt.legend()
plt.grid()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import confusion_matrix

# Convert one-hot to class indices
y_true = np.argmax(y_test_binary, axis=1)
y_pred = np.argmax(y_pred_binary, axis=1)

# Compute confusion matrix
cm = confusion_matrix(y_true, y_pred)
row_totals = cm.sum(axis=1)
cm_percent = cm.astype('float') / row_totals[:, np.newaxis] * 100

# Add a new column with zeros for the "Total" column (for coloring)
cm_percent_extended = np.hstack([cm_percent, np.zeros((cm_percent.shape[0], 1))])

# Create extended annotations with Total
annotations = np.empty_like(cm_percent_extended).astype(str)
for i in range(cm.shape[0]):
    for j in range(cm.shape[1]):
        count = cm[i, j]
        percent = cm_percent[i, j]
        annotations[i, j] = f"{percent:.2f}%\n{count}"
    # Add total count annotation to last column
    annotations[i, -1] = f"{row_totals[i]}"

# Updated labels
attack_labels = ["Benign", "DDoS_LOIT", "DoS_GoldenEye", "DoS_Hulk", "DoS_Slowhttptest", "DoS_Slowloris"]
xtick_labels = attack_labels + ["Total"]

# Set up the plot
plt.figure(figsize=(11, 8))  # Slightly wider for the extra column

# Use matching light cyan/blue color map
cmap = sns.light_palette("cadetblue", as_cmap=True)

# Plot heatmap
sns.heatmap(cm_percent_extended, annot=annotations, fmt='', cmap=cmap, cbar=False,
            xticklabels=xtick_labels, yticklabels=attack_labels,
            annot_kws={"size": 10, "color": "black"})

# Formatting
plt.xticks(rotation=30, ha='right', fontsize=10)
plt.yticks(rotation=0, fontsize=10)
plt.xlabel('Predicted Label', fontsize=12)
plt.ylabel('True Label', fontsize=12)
plt.title('Confusion Matrix', fontsize=14)
plt.tight_layout()
plt.show()
